# %% [markdown]
# <a href="https://colab.research.google.com/github/thisisindrajit/Athena/blob/main/code%20-%20full%20version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Thumbnail.png](data:image/png;base64,...)

# %% [markdown]
# # Athena - Portfolio Optimization using Machine Learning
#
# Athena uses a novel approach to portfolio optimization. It combines both deep learning and statistics along with asset fundamentals analysis to generate a robust portfolio consisting of value stocks with maximal returns and minimal risk, especially useful for long term investors.

# %% [markdown]
# ## Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Imports

# %%
# !pip install yfinance
# !pip install PyPortfolioOpt
# !pip install Riskfolio-Lib
# !pip install ffn
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: PyPortfolioOpt in /usr/local/lib/python3.7/dist-packages (1.5.2)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.2.0)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.3.5)
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.4.1)
# Requirement already satisfied: numpy<2.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.21.6)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (3.2.0)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post0)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.10)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->PyPortfolioOpt) (1.15.0)
# Requirement already satisfied: Riskfolio-Lib in /usr/local/lib/python3.7/dist-packages (3.1.1)
# Requirement already satisfied: xlsxwriter>=1.3.7 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (3.0.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (3.5.2)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (2.6.3)
# Requirement already satisfied: cvxpy>=1.0.25 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (1.2.0)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (1.4.1)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (1.0.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (1.21.6)
# Requirement already satisfied: statsmodels>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (0.13.2)
# Requirement already satisfied: arch>=4.15 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (5.2.0)
# Requirement already satisfied: astropy>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from Riskfolio-Lib) (4.3.1)
# Requirement already satisfied: property-cached>=1.6.4 in /usr/local/lib/python3.7/dist-packages (from arch>=4.15->Riskfolio-Lib) (1.6.4)
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from astropy>=4.3.1->Riskfolio-Lib) (2.0.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from astropy>=4.3.1->Riskfolio-Lib) (4.11.3)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.7/dist-packages (from cvxpy>=1.0.25->Riskfolio-Lib) (3.2.0)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy>=1.0.25->Riskfolio-Lib) (0.6.2.post0)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy>=1.0.25->Riskfolio-Lib) (2.0.10)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->Riskfolio-Lib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->Riskfolio-Lib) (3.0.8)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->Riskfolio-Lib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->Riskfolio-Lib) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->Riskfolio-Lib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->Riskfolio-Lib) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->Riskfolio-Lib) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.0->Riskfolio-Lib) (4.2.0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy>=1.0.25->Riskfolio-Lib) (0.1.5.post2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->Riskfolio-Lib) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->Riskfolio-Lib) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.0->Riskfolio-Lib) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.0->Riskfolio-Lib) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.10.1->Riskfolio-Lib) (0.5.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy>=4.3.1->Riskfolio-Lib) (3.8.0)
# Requirement already satisfied: ffn in /usr/local/lib/python3.7/dist-packages (0.3.6)
# Requirement already satisfied: tabulate>=0.7.5 in /usr/local/lib/python3.7/dist-packages (from ffn) (0.8.9)
# Requirement already satisfied: matplotlib>=1 in /usr/local/lib/python3.7/dist-packages (from ffn) (3.5.2)
# Requirement already satisfied: decorator>=4 in /usr/local/lib/python3.7/dist-packages (from ffn) (4.4.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from ffn) (1.3.5)
# Requirement already satisfied: numpy>=1.5 in /usr/local/lib/python3.7/dist-packages (from ffn) (1.21.6)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.7/dist-packages (from ffn) (0.9.0)
# Requirement already satisfied: scikit-learn>=0.15 in /usr/local/lib/python3.7/dist-packages (from ffn) (1.0.2)
# Requirement already satisfied: scipy>=0.15 in /usr/local/lib/python3.7/dist-packages (from ffn) (1.4.1)
# Requirement already satisfied: future>=0.15 in /usr/local/lib/python3.7/dist-packages (from ffn) (0.16.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1->ffn) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1->ffn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1->ffn) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1->ffn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1->ffn) (3.0.8)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1->ffn) (4.33.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1->ffn) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=1->ffn) (4.2.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->ffn) (2022.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandas-datareader>=0.2->ffn) (4.8.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader>=0.2->ffn) (2.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=1->ffn) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (2.0.12)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15->ffn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15->ffn) (1.1.0)

# %%
import yfinance as yf
import math
import ffn
import riskfolio as rp
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
from keras.layers.core import Dense, Dropout, Flatten
from keras.layers.recurrent import LSTM, GRU
from keras.models import Sequential, load_model
# from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import tensorflow.keras.backend as K
import scipy
import pandas as pd
# from pandas_datareader import data as pdr
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

print("-----------------------------")
print(f'Tensorflow version: {tf.__version__}')
# print(f'Matplotlib version: {matplotlib.__version__}')
print("All neccessary imports done!")
# Out:
# -----------------------------
# Tensorflow version: 2.8.0
# All neccessary imports done!

# %% [markdown]
# ## Variables

# %% [markdown]
# **Sample Portfolio 1 [Random selection]**
#
# 1. Asian Paints - ASIANPAINT.NS
# 1. Reliance - RELIANCE.NS
# 1. Pidilite Industries - PIDILITIND.NS
# 1. Lupin - LUPIN.NS
# 1. Indian Oil Corporation - IOC.NS
#
# tickers = ["ASIANPAINT.NS", "RELIANCE.NS", "PIDILITIND.NS", "LUPIN.NS", "IOC.NS"]
#
# ---
#
# **Sample Portfolio 2 [Selected based on popularity and market cap]**
#
# 1. Adani Ports - ADANIPORTS.NS
# 1. Asian Paints - ASIANPAINT.NS
# 1. Reliance - RELIANCE.NS
# 1. ICICI Bank - ICICIBANK.NS
# 1. Cipla - CIPLA.NS
# 1. Infosys -  INFY.NS
# 1. Lupin - LUPIN.NS
# 1. HDFC Bank - HDFCBANK.NS
# 1. TCS - TCS.NS
# 1. Airtel - BHARTIARTL.NS
#
# tickers = ["ADANIPORTS.NS", "ASIANPAINT.NS", "RELIANCE.NS", "ICICIBANK.NS", "CIPLA.NS", "INFY.NS", "LUPIN.NS", "HDFCBANK.NS", "TCS.NS", "BHARTIARTL.NS"]
#
# ---
#
# **Sample Portfolio 3 [Selected based on financial news sites suggestions without any fundamental analysis]**
#
# 1. Coforge - COFORGE.NS
# 1. State bank of India - SBIN.NS
# 1. Blue star - BLUESTARCO.NS
# 1. Zen Technologies - ZENTEC.NS
# 1. Cummins India - CUMMINSIND.NS
# 1. Trent - TRENT.NS
# 1. Tata Power - TATAPOWER.NS
# 1. Vardhman Textiles - VTL.NS
# 1. Birlasoft - BSOFT.NS
# 1. APL Apollo Tubes - APLAPOLLO.NS
# 1. Dhampur Sugar Mills - DHAMPURSUG.NS
#
# tickers = ["COFORGE.NS", "SBIN.NS", "BLUESTARCO.NS", "ZENTEC.NS", "CUMMINSIND.NS", "TRENT.NS", "TATAPOWER.NS", "VTL.NS", "BSOFT.NS", "APLAPOLLO.NS", "DHAMPURSUG.NS"]
#
# ---
#
# **Sample Portfolio 4 [Value stocks selected based on fundamental analysis]**
#
# 1. Lincoln pharma - LINCOLN.NS
# 1. Aarti Drugs - AARTIDRUGS.NS
# 1. Glenmark Life Sciences - GLS.NS (Less data)
# 1. Thirumalai Chemicals Ltd - TIRUMALCHM.NS
# 1. S P Apparels Ltd - SPAL.NS
# 1. ICICI securities - ISEC.NS
# 1. Shyam Metallics - SHYAMMETL.NS (Less data)
# 1. GTPL Hathway - GTPL.NS
# 1. Birlasoft - BSOFT.NS
#
# tickers = ["LINCOLN.NS", "AARTIDRUGS.NS", "GLS.NS", "TIRUMALCHM.NS", "SPAL.NS", "ISEC.NS", "SHYAMMETL.NS", "GTPL.NS", "BSOFT.NS"]
#
# ---
#
# **Sample Portfolio 5 [Combination of sample portfolio 4 and 5]**
#
# 1. Coforge - COFORGE.NS
# 1. State bank of India - SBIN.NS
# 1. Tata Power - TATAPOWER.NS
# 1. Birlasoft - BSOFT.NS
# 1. APL Apollo Tubes - APLAPOLLO.NS
# 1. Dhampur Sugar Mills - DHAMPURSUG.NS
# 1. Lincoln pharma - LINCOLN.NS
# 1. Aarti Drugs - AARTIDRUGS.NS
# 1. Thirumalai Chemicals Ltd - TIRUMALCHM.NS
# 1. ICICI securities - ISEC.NS
#
#
# tickers = ["COFORGE.NS", "SBIN.NS", "TATAPOWER.NS", "BSOFT.NS", "APLAPOLLO.NS", "DHAMPURSUG.NS", "LINCOLN.NS", "AARTIDRUGS.NS", "TIRUMALCHM.NS", "ISEC.NS"]

# %%
tickers = ["ADANIPORTS.NS", "ASIANPAINT.NS", "RELIANCE.NS", "ICICIBANK.NS", "CIPLA.NS", 
           "INFY.NS", "LUPIN.NS", "HDFCBANK.NS", "TCS.NS", "BHARTIARTL.NS"]
# sorting tickers
tickers.sort()

# time_steps = 100 # the lookback period
# features = 1 # We use only the close price
min_prev_days = 252
port_len = len(tickers) # length of portfolio
max_port_len = 15 # maximum length of portfolio that is allowed

# %% [markdown]
# ## Getting data from API (YFinance)
#
# Reference - https://pypi.org/project/yfinance/

# %%
def get_data(tickers, period="5y"):

  if port_len > max_port_len:
    print(f'Only {max_port_len} number of assets allowed in portfolio!')
    return None
  
  # download data of ticker symbols
  data = yf.download(tickers, period=period)
  
  # check whether if any ticker symbol has less than min_prev_days days of data
  for i in range(port_len):
    cur_ticker_count = data.iloc[:, i].count()
    print(f'No of rows available for {tickers[i]} is {cur_ticker_count}')

    if cur_ticker_count < min_prev_days:
      print(f'{tickers[i]} has less than {min_prev_days} days of historical price data. Please consider removing the asset or adding some other asset.')
      return None
    
  # remove open, high, low, volume, adj close columns
  data = data.drop("Open", axis = 1)
  data = data.drop("High", axis = 1)
  data = data.drop("Low", axis = 1)
  data = data.drop("Volume", axis = 1)
  data = data.drop("Adj Close", axis = 1)

  return data

# %%
# valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max

df = get_data(tickers, period="5y")
extra_info_tickers = yf.Tickers(tickers)
# Out:
# [*********************100%***********************]  10 of 10 completed
# No of rows available for ADANIPORTS.NS is 1236
# No of rows available for ASIANPAINT.NS is 1236
# No of rows available for BHARTIARTL.NS is 1236
# No of rows available for CIPLA.NS is 1236
# No of rows available for HDFCBANK.NS is 1236
# No of rows available for ICICIBANK.NS is 1236
# No of rows available for INFY.NS is 1236
# No of rows available for LUPIN.NS is 1236
# No of rows available for RELIANCE.NS is 1236
# No of rows available for TCS.NS is 1236

# %%
df = df.dropna()
df = df["Close"]
df
# Out:
#             ADANIPORTS.NS  ASIANPAINT.NS  BHARTIARTL.NS    CIPLA.NS  \
# Date
# 2017-05-08     340.500000    1167.349976     322.556061  551.549988
# 2017-05-09     347.500000    1165.300049     317.001068  552.950012
# 2017-05-10     351.899994    1158.300049     342.250977  561.049988
# 2017-05-11     360.049988    1166.449951     336.053284  561.950012
# 2017-05-12     357.950012    1132.949951     335.226929  567.950012
# ...                   ...            ...            ...         ...
# 2022-04-29     856.400024    3237.199951     739.000000  981.200012
# 2022-05-02     856.549988    3200.000000     741.349976  976.599976
# 2022-05-04     812.799988    3100.850098     722.400024  957.549988
# 2022-05-05     811.349976    3076.550049     718.950012  948.400024
# 2022-05-06     811.400024    3016.250000     710.250000  934.750000
#
#             HDFCBANK.NS  ICICIBANK.NS      INFY.NS     LUPIN.NS  RELIANCE.NS  \
# Date
# 2017-05-08   767.400024    275.409088   472.750000  1279.800049   654.496033
# 2017-05-09   767.875000    273.272736   473.325012  1250.150024   658.929016
# 2017-05-10   775.900024    271.500000   471.825012  1258.900024   673.169006
# 2017-05-11   773.200012    272.909088   472.049988  1259.699951   673.391907
# 2017-05-12   775.825012    269.590912   482.125000  1253.949951   668.884644
# ...                 ...           ...          ...          ...          ...
# 2022-04-29  1384.599976    743.299988  1567.550049   744.650024  2790.250000
# 2022-05-02  1403.699951    741.000000  1541.000000   741.849976  2780.449951
# 2022-05-04  1356.000000    724.250000  1535.550049   726.750000  2693.649902
# 2022-05-05  1352.949951    728.799988  1585.150024   726.349976  2640.899902
# 2022-05-06  1317.599976    719.250000  1542.849976   723.849976  2620.649902
#
#                  TCS.NS
# Date
# 2017-05-08  1171.224976
# 2017-05-09  1176.275024
# 2017-05-10  1166.224976
# 2017-05-11  1174.724976
# 2017-05-12  1180.324951
# ...                 ...
# 2022-04-29  3546.699951
# 2022-05-02  3542.399902
# 2022-05-04  3479.750000
# 2022-05-05  3513.399902
# 2022-05-06  3432.600098
#
# [1236 rows x 10 columns]

# %% [markdown]
# ## Converting company information to DataFrame

# %%
# Information of the company of first ticker symbol
infodf0 = pd.DataFrame.from_dict(extra_info_tickers.tickers[tickers[0]].info,orient='index')
infodf0 = infodf0.reset_index()
infodf0
# Out:
#                    index                                                  0
# 0                    zip                                             382421
# 1                 sector                                        Industrials
# 2      fullTimeEmployees                                               2773
# 3    longBusinessSummary  Adani Ports and Special Economic Zone Limited,...
# 4                   city                                          Ahmedabad
# ..                   ...                                                ...
# 148              bidSize                                                  0
# 149              dayHigh                                             820.95
# 150   regularMarketPrice                                              811.4
# 151       preMarketPrice                                               None
# 152             logo_url           https://logo.clearbit.com/adaniports.com
#
# [153 rows x 2 columns]

# %% [markdown]
# ## Visualizing the data

# %%
# Pandas has inbuilt support for matplotlib, so we can use plot function directly

df.plot(label = tickers, figsize = (15,7))
plt.show()

# %% [markdown]
# ## Geting information like balance sheet, cashflow etc. from YFinance API

# %% [markdown]
# ### Earnings

# %%
extra_info_tickers.tickers[tickers[8]].earnings
# Out:
#           Revenue    Earnings
# Year
# 2018  21574600000   869700000
# 2019  26302400000   969600000
# 2020  34859800000  1228500000
# 2021  25929600000 -1461700000

# %% [markdown]
# ### Balance sheet

# %%
extra_info_tickers.tickers[tickers[4]].balance_sheet
# Out:
#                                     2021-03-31    2020-03-31    2019-03-31  \
# Intangible Assets                 2.667000e+08  2.038000e+08  1.684000e+08
# Capital Surplus                   2.682000e+08  2.440000e+08  2.440000e+08
# Total Liab                        6.358800e+10  3.233280e+10  3.617320e+10
# Total Stockholder Equity          1.822110e+10  1.209540e+10  1.047270e+10
# Other Current Liab                1.044620e+10  2.694600e+09  2.326400e+09
# Total Assets                      8.180910e+10  4.442820e+10  4.664590e+10
# Common Stock                      1.611100e+09  1.610700e+09  1.610700e+09
# Other Current Assets              3.856210e+10  2.212480e+10  1.425420e+10
# Retained Earnings                 1.572650e+10  9.776300e+09  8.280100e+09
# Other Liab                        3.342000e+09  3.567600e+09  3.318400e+09
# Treasury Stock                    6.153000e+08  4.644000e+08  3.379000e+08
# Other Assets                      5.601000e+08  5.955000e+08  7.375000e+08
# Cash                              3.093500e+09  5.420000e+09  1.884110e+10
# Total Current Liabilities         5.919220e+10  2.724590e+10  3.285480e+10
# Deferred Long Term Asset Charges  5.601000e+08  5.955000e+08  7.375000e+08
# Other Stockholder Equity          6.153000e+08  4.644000e+08  3.379000e+08
# Property Plant Equipment          1.421400e+09  1.857200e+09  3.072000e+08
# Total Current Assets              7.952320e+10  4.175700e+10  4.540320e+10
# Long Term Investments             3.770000e+07  1.470000e+07  2.960000e+07
# Net Tangible Assets               1.795440e+10  1.189160e+10  1.030430e+10
# Net Receivables                   3.497710e+10  7.586400e+09  9.716300e+09
# Accounts Payable                  1.026460e+10  6.926400e+09  2.336200e+10
#
#                                     2018-03-31
# Intangible Assets                 1.092000e+08
# Capital Surplus                   2.440000e+08
# Total Liab                        2.026190e+10
# Total Stockholder Equity          8.477100e+09
# Other Current Liab                1.628100e+09
# Total Assets                      2.873900e+10
# Common Stock                      1.610700e+09
# Other Current Assets              1.517500e+10
# Retained Earnings                 6.349800e+09
# Other Liab                        2.900200e+09
# Treasury Stock                    2.726000e+08
# Other Assets                      6.662000e+08
# Cash                              1.770700e+09
# Total Current Liabilities         1.736170e+10
# Deferred Long Term Asset Charges  6.661000e+08
# Other Stockholder Equity          2.726000e+08
# Property Plant Equipment          3.121000e+08
# Total Current Assets              2.762400e+10
# Long Term Investments             2.750000e+07
# Net Tangible Assets               8.367900e+09
# Net Receivables                   1.025940e+10
# Accounts Payable                  6.116800e+09

# %% [markdown]
# ### Cashflow

# %%
extra_info_tickers.tickers[tickers[3]].cashflow
# Out:
#                                              2021-03-31    2020-03-31  \
# Change To Liabilities                      0.000000e+00  0.000000e+00
# Total Cashflows From Investing Activities -3.750200e+09 -2.578340e+09
# Net Borrowings                            -6.365600e+08 -1.310280e+09
# Total Cash From Financing Activities      -1.630680e+09 -1.866350e+09
# Change To Operating Activities             9.619400e+08  1.079000e+08
# Net Income                                 1.881020e+09  7.774500e+08
# Change In Cash                             9.583000e+07 -4.655400e+08
# Total Cash From Operating Activities       5.476710e+09  3.936730e+09
# Depreciation                               2.531350e+09  2.320790e+09
# Other Cashflows From Investing Activities  2.923000e+07  5.009000e+07
# Dividends Paid                            -3.373900e+08 -1.124800e+08
# Change To Inventory                        1.464800e+08  2.439000e+07
# Change To Account Receivables             -1.209750e+09 -1.268760e+09
# Other Cashflows From Financing Activities -6.567300e+08 -4.435900e+08
# Change To Netincome                        9.871100e+08  1.906740e+09
# Capital Expenditures                      -3.709680e+09 -2.506740e+09
# Investments                                         NaN -1.400000e+06
# Issuance Of Stock                                   NaN           NaN
#
#                                              2019-03-31    2018-03-31
# Change To Liabilities                      0.000000e+00  0.000000e+00
# Total Cashflows From Investing Activities -2.349170e+09 -3.344440e+09
# Net Borrowings                             1.679500e+08 -2.189250e+09
# Total Cash From Financing Activities      -5.368000e+07 -6.443900e+08
# Change To Operating Activities             2.874900e+08  1.563290e+09
# Net Income                                 1.888100e+08  6.109600e+08
# Change In Cash                             4.415900e+08  1.340600e+08
# Total Cash From Operating Activities       2.844440e+09  4.122890e+09
# Depreciation                               1.923860e+09  1.668730e+09
# Other Cashflows From Investing Activities  4.821000e+07  3.954000e+07
# Dividends Paid                            -1.124600e+08 -1.124600e+08
# Change To Inventory                       -2.496900e+08 -2.496900e+08
# Change To Account Receivables             -5.115200e+08 -4.756900e+08
# Other Cashflows From Financing Activities -1.091700e+08 -7.427100e+08
# Change To Netincome                        1.157760e+09  7.135900e+08
# Capital Expenditures                      -2.274730e+09 -3.282810e+09
# Investments                                9.080000e+06 -3.191000e+07
# Issuance Of Stock                                   NaN  2.400030e+09

# %% [markdown]
# ### Financials

# %%
extra_info_tickers.tickers[tickers[6]].financials
# Out:
#                                              2021-03-31       2020-03-31  \
# Research Development                               None             None
# Effect Of Accounting Charges                       None             None
# Income Before Tax                        238878149000.0   211399689000.0
# Minority Interest                         96259166000.0    79438220000.0
# Net Income                               224054576000.0   197678022000.0
# Selling General Administrative           732218984000.0   673098139000.0
# Gross Profit                            1747093147000.0  1499583915000.0
# Ebit                                                0.0              0.0
# Operating Income                         242797194000.0   181768285000.0
# Other Operating Expenses                 772076969000.0   644717491000.0
# Interest Expense                                   None             None
# Extraordinary Items                                None             None
# Non Recurring                                      None             None
# Other Items                                        None             None
# Income Tax Expense                                  0.0              0.0
# Total Revenue                           1747093147000.0  1499583915000.0
# Total Operating Expenses                1504295953000.0  1317815630000.0
# Cost Of Revenue                                     0.0              0.0
# Total Other Income Expense Net            -3919045000.0    29631404000.0
# Discontinued Operations                            None             None
# Net Income From Continuing Ops           238878149000.0   211399689000.0
# Net Income Applicable To Common Shares   224054576000.0   197678022000.0
#
#                                              2019-03-31      2018-03-31
# Research Development                               None            None
# Effect Of Accounting Charges                       None            None
# Income Before Tax                         33505535000.0 -118067540000.0
# Minority Interest                         60369913000.0   46152451000.0
# Net Income                                22996391000.0  -45562900000.0
# Selling General Administrative           611819825000.0  517318804000.0
# Gross Profit                            1178693821000.0  839096052000.0
# Ebit                                                0.0             0.0
# Operating Income                          30690741000.0 -122449138000.0
# Other Operating Expenses                 536183255000.0  444226386000.0
# Interest Expense                                   None            None
# Extraordinary Items                                None            None
# Non Recurring                                      None            None
# Other Items                                        None            None
# Income Tax Expense                                  0.0  -80575000000.0
# Total Revenue                           1178693821000.0  839096052000.0
# Total Operating Expenses                1148003080000.0  961545190000.0
# Cost Of Revenue                                     0.0             0.0
# Total Other Income Expense Net             2814794000.0    4381598000.0
# Discontinued Operations                            None            None
# Net Income From Continuing Ops            33505535000.0  -37492540000.0
# Net Income Applicable To Common Shares    22996391000.0  -45562900000.0

# %% [markdown]
# # Using FFN library for performance evaluation of different assets

# %% [markdown]
# ### Total returns

# %%
for i in range(port_len):
  print(f'Total return of {tickers[i]} - {round(ffn.core.calc_total_return(df[tickers[i]]) * 100, 2)}%')
# Out:
# Total return of AARTIDRUGS.NS - 227.14%
# Total return of APLAPOLLO.NS - 377.97%
# Total return of BSOFT.NS - 197.68%
# Total return of COFORGE.NS - 368.48%
# Total return of DHAMPURSUG.NS - 263.37%
# Total return of ISEC.NS - 16.9%
# Total return of LINCOLN.NS - 43.16%
# Total return of SBIN.NS - 93.95%
# Total return of TATAPOWER.NS - 194.94%
# Total return of TIRUMALCHM.NS - 42.78%

# %% [markdown]
# ### CAGR (Compound Annual Growth Rate)

# %%
for i in range(port_len):
  print(f'CAGR of {tickers[i]} - {round(ffn.core.calc_cagr(df[tickers[i]]) * 100, 2)}%')
# Out:
# CAGR of AARTIDRUGS.NS - 33.69%
# CAGR of APLAPOLLO.NS - 46.7%
# CAGR of BSOFT.NS - 30.63%
# CAGR of COFORGE.NS - 45.98%
# CAGR of DHAMPURSUG.NS - 37.17%
# CAGR of ISEC.NS - 3.9%
# CAGR of LINCOLN.NS - 9.19%
# CAGR of SBIN.NS - 17.62%
# CAGR of TATAPOWER.NS - 30.34%
# CAGR of TIRUMALCHM.NS - 9.12%

# %% [markdown]
# # Deep Learning model for future price prediction [Not important]

# %% [markdown]
# ## Preprocessing

# %%
# shifting is done here to ensure that the next day's price is predicted on the given day
df_shift = df.shift(-1)

label = df_shift

print(label)
# Out:
#             ASIANPAINT.NS      IOC.NS     LUPIN.NS  PIDILITIND.NS  RELIANCE.NS
# Date
# 2017-03-23    1064.250000  186.350006  1487.800049     688.250000   637.333740
# 2017-03-24    1042.900024  185.449997  1457.750000     682.900024   619.676086
# 2017-03-27    1057.849976  184.524994  1455.699951     696.500000   617.026184
# 2017-03-28    1068.099976  185.074997  1454.349976     689.099976   622.425049
# 2017-03-29    1070.099976  188.399994  1446.949951     690.950012   629.359314
# ...                   ...         ...          ...            ...          ...
# 2022-03-16    3136.600098  121.349998   765.349976    2510.399902  2481.699951
# 2022-03-17    3045.750000  118.000000   755.150024    2485.250000  2467.399902
# 2022-03-21    3051.149902  120.650002   757.250000    2450.350098  2531.149902
# 2022-03-22    3007.300049  121.199997   752.500000    2421.899902  2542.000000
# 2022-03-23            NaN         NaN          NaN            NaN          NaN
#
# [1236 rows x 5 columns]

# %%
# adjusting the shape of both df and label (since label contains NaN as the last value)

df.drop(df.index[len(df)-1], axis=0, inplace=True)
label.drop(label.index[len(label)-1], axis=0, inplace=True)

# %%
df
# Out:
#             ASIANPAINT.NS      IOC.NS     LUPIN.NS  PIDILITIND.NS  RELIANCE.NS
# Date
# 2017-03-23    1061.599976  188.399994  1490.250000     693.849976   630.671875
# 2017-03-24    1064.250000  186.350006  1487.800049     688.250000   637.333740
# 2017-03-27    1042.900024  185.449997  1457.750000     682.900024   619.676086
# 2017-03-28    1057.849976  184.524994  1455.699951     696.500000   617.026184
# 2017-03-29    1068.099976  185.074997  1454.349976     689.099976   622.425049
# ...                   ...         ...          ...            ...          ...
# 2022-03-15    2987.149902  119.000000   737.950012    2370.550049  2363.449951
# 2022-03-16    3042.000000  121.949997   749.599976    2462.899902  2403.350098
# 2022-03-17    3136.600098  121.349998   765.349976    2510.399902  2481.699951
# 2022-03-21    3045.750000  118.000000   755.150024    2485.250000  2467.399902
# 2022-03-22    3051.149902  120.650002   757.250000    2450.350098  2531.149902
#
# [1235 rows x 5 columns]

# %%
label
# Out:
#             ASIANPAINT.NS      IOC.NS     LUPIN.NS  PIDILITIND.NS  RELIANCE.NS
# Date
# 2017-03-23    1064.250000  186.350006  1487.800049     688.250000   637.333740
# 2017-03-24    1042.900024  185.449997  1457.750000     682.900024   619.676086
# 2017-03-27    1057.849976  184.524994  1455.699951     696.500000   617.026184
# 2017-03-28    1068.099976  185.074997  1454.349976     689.099976   622.425049
# 2017-03-29    1070.099976  188.399994  1446.949951     690.950012   629.359314
# ...                   ...         ...          ...            ...          ...
# 2022-03-15    3042.000000  121.949997   749.599976    2462.899902  2403.350098
# 2022-03-16    3136.600098  121.349998   765.349976    2510.399902  2481.699951
# 2022-03-17    3045.750000  118.000000   755.150024    2485.250000  2467.399902
# 2022-03-21    3051.149902  120.650002   757.250000    2450.350098  2531.149902
# 2022-03-22    3007.300049  121.199997   752.500000    2421.899902  2542.000000
#
# [1235 rows x 5 columns]

# %% [markdown]
# #### For portfolio [not important]

# %%
df["ASIANPAINT.NS"].values.reshape(-1,1)
# Out:
# array([[1061.59997559],
#        [1064.25      ],
#        [1042.90002441],
#        ...,
#        [2987.14990234],
#        [3042.        ],
#        [3136.60009766]])

# %%
x_scale = MinMaxScaler(feature_range=(0,1))
y_scale = MinMaxScaler(feature_range=(0,1))
X = []
Y = []

for t in tickers:
  scaled_t = x_scale.fit_transform(df[t].values.reshape(-1,1))
  scaled_label = y_scale.fit_transform(label[t].values.reshape(-1,1))
  
  X.append(scaled_t)
  Y.append(scaled_label)

X = np.array(X)
Y = np.array(Y)

print(X.shape)
print(Y.shape)
# Out:
# (5, 1233, 1)
# (5, 1233, 1)

# %% [markdown]
# #### For single asset and portfolio

# %%
# conversion to numpy array

x, y = df.values, label.values

# %%
# Scaling to normalize the data. MinMaxScaler scales all the data to be in the region of 0 and 1.

x_scale = MinMaxScaler(feature_range=(0,1))
y_scale = MinMaxScaler(feature_range=(0,1))

# %%
X = x_scale.fit_transform(x)
Y = y_scale.fit_transform(y.reshape(-1,port_len))

print(X.shape)
print(Y.shape)

print(X[0])
print(Y[time_steps])
# Out:
# (1235, 5)
# (1235, 5)
# [0.00834041 0.74999993 1.         0.0053002  0.0064524 ]
# [0.03925707 0.9122272  0.41529208 0.06711196 0.07720612]

# %% [markdown]
# ## Splitting train/test data and adding timesteps [Best Method]

# %% [markdown]
# ### For portfolio [not important]

# %%
X_train_new = []
y_train_new = []
X_test_new = []
y_test_new = []

for i in range(len(X)):
  X_train, X_test, y_train, y_test = train_test_split(X[i], Y[i], test_size=0.4, shuffle=False)
  X_train_new.append(X_train)
  X_test_new.append(X_test)
  y_train_new.append(y_train)
  y_test_new.append(y_test)

X_train_new = np.array(X_train_new)
y_train_new = np.array(y_train_new)

print(X_train_new.shape)
print(y_train_new.shape)

X_test_new = np.array(X_test_new)
y_test_new = np.array(y_test_new)

print(X_test_new.shape)
print(y_test_new.shape)
# Out:
# (5, 739, 1)
# (5, 739, 1)
# (5, 494, 1)
# (5, 494, 1)

# %% [markdown]
# ### For single asset and portfolio

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.4, shuffle=False)

# %%
print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (741, 5)
# (741, 5)
# (494, 5)
# (494, 5)

# %% [markdown]
# #### Adding timesteps [Best Method]

# %%
X_train_new = []
y_train_new = []
X_test_new = []
y_test_new = []

for i in range(time_steps, len(X_train)):
  X_train_new.append(X_train[i-time_steps:i, :])
  y_train_new.append(y_train[i-1])
  


for i in range(time_steps, len(X_test)):
  X_test_new.append(X_test[i-time_steps:i, :])
  y_test_new.append(y_test[i-1])

# %% [markdown]
# #### Converting train and test to numpy arrays and reshaping

# %%
X_train_new = np.array(X_train_new)
y_train_new = np.array(y_train_new)

print(X_train_new.shape)
print(y_train_new.shape)

X_test_new = np.array(X_test_new)
y_test_new = np.array(y_test_new)

print(X_test_new.shape)
print(y_test_new.shape)
# Out:
# (641, 100, 5)
# (641, 5)
# (394, 100, 5)
# (394, 5)

# %%
y_train_new[0]
# Out:
# array([0.03726561, 0.90885743, 0.43189316, 0.06549044, 0.07526218])

# %%
X_train_new = X_train_new.reshape(-1,time_steps,port_len)
X_test_new = X_test_new.reshape(-1,time_steps,port_len)

# %% [markdown]
# ## Using timesteps (Method 2) [not important]

# %%
scale = MinMaxScaler(feature_range=(0,1))

df = scale.fit_transform(np.array(df).reshape(-1,1))

# %%
# Training data is 60% of the whole data. The rest is test data
training_size=int(len(df)*0.6)
test_size=len(df)-training_size

train_data,test_data=df[0:training_size,:],df[training_size:len(df), :1]

# %%
def create_dataset(dataset, time_step):
  dataX, dataY = [], []

  for i in range(len(dataset)-time_step-1):

    # a = dataset[i:(i+time_step), :]
    a = dataset[i:(i+time_step), 0]
    dataX.append(a)
    # dataY.append(dataset[i + time_step, 3])
    dataY.append(dataset[i + time_step, 0])

  return np.array(dataX), np.array(dataY)

# %%
X_train, y_train = create_dataset(train_data, time_steps)
X_test, y_test = create_dataset(test_data, time_steps)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (641, 100)
# (394, 100)
# (641,)
# (394,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], features)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], features)

print(X_train.shape)
print(X_test.shape)
# Out:
# (641, 100, 1)
# (394, 100, 1)

# %% [markdown]
# ## Deep learning model (GRU)

# %%
gru_model = Sequential()
gru_model.add(GRU(units=512,
              return_sequences=True,
              input_shape=(time_steps, port_len)))
gru_model.add(Dropout(0.2))

gru_model.add(GRU(units=256))
gru_model.add(Dropout(0.2))

gru_model.add(Dense(port_len))

gru_model.compile(loss='mse', optimizer='adam')

# %%
gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 100, 512)          795648
#
#  dropout_3 (Dropout)         (None, 100, 512)          0
#
#  gru_4 (GRU)                 (None, 256)               590592
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 1,387,525
# Trainable params: 1,387,525
# Non-trainable params: 0
# _________________________________________________________________

# %%
with tf.device('/device:GPU:0'):
  gru_model.fit(X_train_new,y_train_new,batch_size=250, epochs=100, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 9s 1s/step - loss: 0.0700 - val_loss: 0.0223
# Epoch 2/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0133 - val_loss: 0.0063
# Epoch 3/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0099 - val_loss: 0.0117
# Epoch 4/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0068 - val_loss: 0.0064
# Epoch 5/100
# 3/3 [==============================] - 3s 998ms/step - loss: 0.0037 - val_loss: 0.0050
# Epoch 6/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 7/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 8/100
# 3/3 [==============================] - 3s 979ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 9/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 10/100
# 3/3 [==============================] - 3s 994ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 11/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 12/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 13/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 14/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 15/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 16/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 17/100
# 3/3 [==============================] - 3s 994ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 18/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 19/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 20/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 21/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0012 - val_loss: 9.6948e-04
# Epoch 22/100
# 3/3 [==============================] - 3s 998ms/step - loss: 0.0013 - val_loss: 9.8472e-04
# Epoch 23/100
# 3/3 [==============================] - 3s 997ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 24/100
# 3/3 [==============================] - 3s 986ms/step - loss: 0.0012 - val_loss: 9.4801e-04
# Epoch 25/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 26/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0013 - val_loss: 9.9605e-04
# Epoch 27/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 8.4774e-04
# Epoch 28/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 8.6719e-04
# Epoch 29/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 7.8285e-04
# Epoch 30/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 8.8383e-04
# Epoch 31/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 8.3402e-04
# Epoch 32/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 9.5430e-04
# Epoch 33/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 8.3993e-04
# Epoch 34/100
# 3/3 [==============================] - 3s 983ms/step - loss: 0.0010 - val_loss: 7.9851e-04
# Epoch 35/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 9.0809e-04
# Epoch 36/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 8.8878e-04
# Epoch 37/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0010 - val_loss: 9.5634e-04
# Epoch 38/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 8.0545e-04
# Epoch 39/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 7.5036e-04
# Epoch 40/100
# 3/3 [==============================] - 3s 991ms/step - loss: 0.0010 - val_loss: 7.7502e-04
# Epoch 41/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0010 - val_loss: 7.9025e-04
# Epoch 42/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.5136e-04 - val_loss: 8.6583e-04
# Epoch 43/100
# 3/3 [==============================] - 3s 991ms/step - loss: 9.7165e-04 - val_loss: 9.0591e-04
# Epoch 44/100
# 3/3 [==============================] - 3s 1000ms/step - loss: 0.0010 - val_loss: 8.0692e-04
# Epoch 45/100
# 3/3 [==============================] - 3s 988ms/step - loss: 0.0010 - val_loss: 8.9803e-04
# Epoch 46/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0010 - val_loss: 8.8480e-04
# Epoch 47/100
# 3/3 [==============================] - 3s 997ms/step - loss: 9.8912e-04 - val_loss: 9.1357e-04
# Epoch 48/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.8192e-04 - val_loss: 0.0010
# Epoch 49/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0010 - val_loss: 8.7252e-04
# Epoch 50/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.9547e-04 - val_loss: 9.4536e-04
# Epoch 51/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0010 - val_loss: 8.1155e-04
# Epoch 52/100
# 3/3 [==============================] - 3s 990ms/step - loss: 0.0010 - val_loss: 8.5041e-04
# Epoch 53/100
# 3/3 [==============================] - 3s 988ms/step - loss: 9.7798e-04 - val_loss: 7.4861e-04
# Epoch 54/100
# 3/3 [==============================] - 3s 987ms/step - loss: 9.6841e-04 - val_loss: 8.1650e-04
# Epoch 55/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.6201e-04 - val_loss: 8.2152e-04
# Epoch 56/100
# 3/3 [==============================] - 3s 988ms/step - loss: 9.3427e-04 - val_loss: 8.2257e-04
# Epoch 57/100
# 3/3 [==============================] - 3s 986ms/step - loss: 9.9840e-04 - val_loss: 8.8099e-04
# Epoch 58/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.5914e-04 - val_loss: 9.2605e-04
# Epoch 59/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.6585e-04 - val_loss: 9.3636e-04
# Epoch 60/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.6724e-04 - val_loss: 8.4100e-04
# Epoch 61/100
# 3/3 [==============================] - 3s 990ms/step - loss: 9.4894e-04 - val_loss: 8.1323e-04
# Epoch 62/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.7522e-04 - val_loss: 8.5084e-04
# Epoch 63/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.5434e-04 - val_loss: 7.7376e-04
# Epoch 64/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.5008e-04 - val_loss: 9.0014e-04
# Epoch 65/100
# 3/3 [==============================] - 3s 986ms/step - loss: 9.0133e-04 - val_loss: 9.3592e-04
# Epoch 66/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.0109e-04 - val_loss: 8.5178e-04
# Epoch 67/100
# 3/3 [==============================] - 3s 992ms/step - loss: 9.2632e-04 - val_loss: 7.5426e-04
# Epoch 68/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.1784e-04 - val_loss: 8.5988e-04
# Epoch 69/100
# 3/3 [==============================] - 3s 984ms/step - loss: 9.2794e-04 - val_loss: 8.9228e-04
# Epoch 70/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.8600e-04 - val_loss: 8.0173e-04
# Epoch 71/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.8983e-04 - val_loss: 8.8771e-04
# Epoch 72/100
# 3/3 [==============================] - 3s 982ms/step - loss: 8.3373e-04 - val_loss: 7.4392e-04
# Epoch 73/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.4206e-04 - val_loss: 8.6667e-04
# Epoch 74/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.9845e-04 - val_loss: 8.6149e-04
# Epoch 75/100
# 3/3 [==============================] - 3s 996ms/step - loss: 9.6190e-04 - val_loss: 8.6604e-04
# Epoch 76/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.1065e-04 - val_loss: 7.1606e-04
# Epoch 77/100
# 3/3 [==============================] - 3s 1s/step - loss: 9.1200e-04 - val_loss: 8.2609e-04
# Epoch 78/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.6459e-04 - val_loss: 6.8224e-04
# Epoch 79/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.7515e-04 - val_loss: 8.3486e-04
# Epoch 80/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.8459e-04 - val_loss: 9.9923e-04
# Epoch 81/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.8668e-04 - val_loss: 8.5522e-04
# Epoch 82/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.6660e-04 - val_loss: 7.9412e-04
# Epoch 83/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.5141e-04 - val_loss: 8.0382e-04
# Epoch 84/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.4592e-04 - val_loss: 6.6069e-04
# Epoch 85/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.3949e-04 - val_loss: 8.4268e-04
# Epoch 86/100
# 3/3 [==============================] - 3s 998ms/step - loss: 8.5140e-04 - val_loss: 7.2084e-04
# Epoch 87/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.3720e-04 - val_loss: 8.9179e-04
# Epoch 88/100
# 3/3 [==============================] - 3s 977ms/step - loss: 8.4080e-04 - val_loss: 8.2443e-04
# Epoch 89/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.4700e-04 - val_loss: 8.7151e-04
# Epoch 90/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.0637e-04 - val_loss: 7.2064e-04
# Epoch 91/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.2760e-04 - val_loss: 8.2222e-04
# Epoch 92/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.1064e-04 - val_loss: 7.2905e-04
# Epoch 93/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.5883e-04 - val_loss: 7.0432e-04
# Epoch 94/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.3552e-04 - val_loss: 6.9949e-04
# Epoch 95/100
# 3/3 [==============================] - 3s 1s/step - loss: 7.6633e-04 - val_loss: 7.7111e-04
# Epoch 96/100
# 3/3 [==============================] - 3s 999ms/step - loss: 8.3859e-04 - val_loss: 6.9108e-04
# Epoch 97/100
# 3/3 [==============================] - 3s 992ms/step - loss: 7.7028e-04 - val_loss: 7.2851e-04
# Epoch 98/100
# 3/3 [==============================] - 3s 1s/step - loss: 8.1758e-04 - val_loss: 7.7549e-04
# Epoch 99/100
# 3/3 [==============================] - 3s 992ms/step - loss: 7.9875e-04 - val_loss: 6.9877e-04
# Epoch 100/100
# 3/3 [==============================] - 3s 1s/step - loss: 7.9902e-04 - val_loss: 7.1849e-04

# %%
gru_model.save("/content/drive/MyDrive/Sem 8/Sem 8 Proj/Models/GRU_port_len_5_features_1_timesteps_100.h5")
print('GRU Model saved!')
# Out:
# GRU Model saved!

# %% [markdown]
# ## Deep Learning Model (LSTM)

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(units=512,
              return_sequences=True,
              input_shape=(time_steps, port_len)))
lstm_model.add(Dropout(0.2))

lstm_model.add(LSTM(units=256))
lstm_model.add(Dropout(0.2))

lstm_model.add(Dense(port_len))

lstm_model.compile(loss='mse', optimizer='adam')

# %%
lstm_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 512)          1060864
#
#  dropout_5 (Dropout)         (None, 100, 512)          0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 1,849,605
# Trainable params: 1,849,605
# Non-trainable params: 0
# _________________________________________________________________

# %%
with tf.device('/device:GPU:0'):
  lstm_model.fit(X_train_new, y_train_new, batch_size=250, epochs=100, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 13s 3s/step - loss: 0.0691 - val_loss: 0.0210
# Epoch 2/100
# 3/3 [==============================] - 10s 4s/step - loss: 0.0159 - val_loss: 0.0177
# Epoch 3/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0186 - val_loss: 0.0039
# Epoch 4/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0061 - val_loss: 0.0155
# Epoch 5/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 6/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 7/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 8/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 9/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 10/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 11/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 12/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0023 - val_loss: 0.0039
# Epoch 13/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 14/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 15/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 16/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 17/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 18/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 19/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 20/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 21/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 22/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 23/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 24/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 25/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 26/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 27/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 28/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 29/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 30/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 31/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 32/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 33/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 34/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 35/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 36/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 37/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 38/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 39/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 40/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 41/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 42/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 43/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 44/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 45/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 46/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 47/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 48/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 49/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 50/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 51/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 52/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 53/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 54/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 55/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 56/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 57/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 58/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 59/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 60/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 61/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 62/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 63/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 64/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 65/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 66/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 67/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 68/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 69/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 70/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 71/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 72/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 73/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 74/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 75/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 76/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 77/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 78/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 79/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 80/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 81/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 82/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 83/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 84/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 85/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 86/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 87/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 88/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 89/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 90/100
# 3/3 [==============================] - 4s 1s/step - loss: 9.9234e-04 - val_loss: 0.0019
# Epoch 91/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 92/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 93/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 94/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 95/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 96/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 97/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 98/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 99/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 100/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0010 - val_loss: 0.0018

# %%
# Saving the model in drive
lstm_model.save("/content/drive/MyDrive/Sem 8/Sem 8 Proj/Models/LSTM_port_len_5_features_1_timesteps_100.h5")
print('LSTM Model saved!')
# Out:
# LSTM Model saved!

# %% [markdown]
# ## Prediction

# %%
model = lstm_model

# %%
score = model.evaluate(X_test_new, y_test_new)

print('Score: {}'.format(score))

yhat = model.predict(X_test_new)

# inverse transform is used to convert the scaled values back to original values

# predicted output
yhat = y_scale.inverse_transform(yhat)

# original output
y_test = y_scale.inverse_transform(y_test_new)

# Prediction plot
plt.figure(figsize = (30,26))

for i in range(len(tickers)):
  plt.plot(yhat[-100:, i], label = f'Predicted - {tickers[i]}')
  plt.plot(y_test[-100:, i], label = tickers[i])

plt.legend()
# plt.legend(handles = [pred, orig], labels = [[f'Predicted - {x}' for x in tickers], tickers])
plt.show()
# Out:
# 13/13 [==============================] - 2s 129ms/step - loss: 0.0042
# Score: 0.0041625648736953735

# %% [markdown]
# ## Next day stock price prediction (Portfolio)

# %%
load_model = load_model("/content/drive/MyDrive/Sem 8/Sem 8 Proj/Models/GRU_port_len_5_features_1_timesteps_100.h5")
print("Model loaded!")
# Out:
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model loaded!

# %%
df_pred = get_data(tickers, False)
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
df_pred = df_pred["Close"]

# %%
df_pred
# Out:
#             ASIANPAINT.NS      IOC.NS     LUPIN.NS  PIDILITIND.NS  RELIANCE.NS
# Date
# 2017-03-23    1061.599976  188.399994  1490.250000     693.849976   630.671875
# 2017-03-24    1064.250000  186.350006  1487.800049     688.250000   637.333740
# 2017-03-27    1042.900024  185.449997  1457.750000     682.900024   619.676086
# 2017-03-28    1057.849976  184.524994  1455.699951     696.500000   617.026184
# 2017-03-29    1068.099976  185.074997  1454.349976     689.099976   622.425049
# ...                   ...         ...          ...            ...          ...
# 2022-03-16    3042.000000  121.949997   749.599976    2462.899902  2403.350098
# 2022-03-17    3136.600098  121.349998   765.349976    2510.399902  2481.699951
# 2022-03-21    3045.750000  118.000000   755.150024    2485.250000  2467.399902
# 2022-03-22    3051.149902  120.650002   757.250000    2450.350098  2531.149902
# 2022-03-23    3011.800049  121.199997   747.200012    2428.600098  2546.300049
#
# [1236 rows x 5 columns]

# %%
df_pred = df_pred.iloc[len(df_pred) - time_steps:len(df_pred), :]
df_pred = df_pred.values
df_pred
# Out:
# array([[3116.30004883,  128.6499939 ,  881.75      , 2368.        ,
#         2598.60009766],
#        [3100.10009766,  127.94999695,  922.90002441, 2313.64990234,
#         2536.25      ],
#        [3121.80004883,  131.6499939 ,  944.34997559, 2362.94995117,
#         2537.80004883],
#        [3103.35009766,  130.80000305,  930.75      , 2343.75      ,
#         2500.80004883],
#        [3170.64990234,  132.55000305,  935.90002441, 2359.5       ,
#         2483.60009766],
#        [3159.25      ,  134.6499939 ,  934.25      , 2408.        ,
#         2498.85009766],
#        [3138.        ,  140.44999695,  929.29998779, 2382.30004883,
#         2501.94995117],
#        [3145.14990234,  139.69999695,  937.34997559, 2392.10009766,
#         2521.69995117],
#        [3108.30004883,  139.44999695,  942.04998779, 2366.44995117,
#         2549.89990234],
#        [3063.5       ,  133.30000305,  935.65002441, 2474.        ,
#         2554.55004883],
#        [3122.89990234,  132.94999695,  948.25      , 2426.19995117,
#         2593.10009766],
#        [3168.69995117,  132.8500061 ,  944.75      , 2431.55004883,
#         2577.80004883],
#        [3151.69995117,  131.        ,  931.5       , 2444.75      ,
#         2517.89990234],
#        [3230.25      ,  128.44999695,  910.15002441, 2414.44995117,
#         2464.        ],
#        [3226.85009766,  129.3500061 ,  898.70001221, 2439.60009766,
#         2473.30004883],
#        [3261.25      ,  124.5       ,  871.29998779, 2350.        ,
#         2363.75      ],
#        [3185.55004883,  126.15000153,  883.        , 2343.19995117,
#         2385.85009766],
#        [3157.        ,  127.59999847,  894.70001221, 2263.10009766,
#         2351.39990234],
#        [3144.25      ,  125.65000153,  899.25      , 2251.64990234,
#         2492.94995117],
#        [3143.10009766,  120.94999695,  915.34997559, 2232.30004883,
#         2412.60009766],
#        [3144.30004883,  118.80000305,  893.        , 2218.10009766,
#         2441.5       ],
#        [3143.64990234,  118.94999695,  884.40002441, 2205.85009766,
#         2405.39990234],
#        [3138.14990234,  117.69999695,  871.40002441, 2204.44995117,
#         2467.        ],
#        [3180.60009766,  120.65000153,  875.59997559, 2235.        ,
#         2482.85009766],
#        [3110.44995117,  122.19999695,  873.        , 2208.44995117,
#         2408.25      ],
#        [3038.30004883,  120.94999695,  858.25      , 2201.55004883,
#         2362.60009766],
#        [3030.35009766,  120.59999847,  866.15002441, 2213.55004883,
#         2381.85009766],
#        [3108.5       ,  120.40000153,  889.25      , 2232.05004883,
#         2418.10009766],
#        [3178.69995117,  119.69999695,  887.54998779, 2262.75      ,
#         2456.44995117],
#        [3283.14990234,  120.05000305,  883.90002441, 2325.75      ,
#         2458.94995117],
#        [3279.85009766,  118.30000305,  884.        , 2358.10009766,
#         2409.64990234],
#        [3297.5       ,  117.90000153,  943.04998779, 2389.25      ,
#         2380.14990234],
#        [3301.94995117,  115.69999695,  918.84997559, 2407.75      ,
#         2373.19995117],
#        [3298.60009766,  115.75      ,  903.40002441, 2418.25      ,
#         2403.89990234],
#        [3243.69995117,  112.84999847,  874.84997559, 2391.44995117,
#         2340.44995117],
#        [3239.44995117,  108.75      ,  875.15002441, 2405.55004883,
#         2277.35009766],
#        [3271.35009766,  109.5       ,  875.75      , 2410.        ,
#         2311.25      ],
#        [3280.10009766,  109.05000305,  902.34997559, 2434.5       ,
#         2366.10009766],
#        [3267.89990234,  112.15000153,  912.45001221, 2421.39990234,
#         2365.25      ],
#        [3284.80004883,  110.25      ,  897.75      , 2410.19995117,
#         2372.80004883],
#        [3272.39990234,  110.75      ,  916.45001221, 2398.19995117,
#         2370.25      ],
#        [3368.19995117,  112.30000305,  916.59997559, 2472.80004883,
#         2398.39990234],
#        [3367.44995117,  111.5       ,  929.59997559, 2450.25      ,
#         2402.5       ],
#        [3365.69995117,  110.55000305,  937.84997559, 2433.89990234,
#         2359.10009766],
#        [3382.94995117,  111.5       ,  950.75      , 2462.80004883,
#         2368.14990234],
#        [3422.39990234,  112.94999695,  945.25      , 2473.94995117,
#         2403.85009766],
#        [3459.30004883,  114.05000305,  932.34997559, 2599.19995117,
#         2458.10009766],
#        [3526.80004883,  117.25      ,  932.04998779, 2637.94995117,
#         2469.60009766],
#        [3514.64990234,  117.25      ,  923.15002441, 2646.        ,
#         2416.5       ],
#        [3576.30004883,  118.5       ,  916.04998779, 2723.44995117,
#         2436.        ],
#        [3553.5       ,  119.69999695,  938.29998779, 2709.14990234,
#         2438.        ],
#        [3538.75      ,  118.59999847,  946.04998779, 2709.75      ,
#         2455.55004883],
#        [3543.80004883,  119.15000153,  952.84997559, 2748.85009766,
#         2521.10009766],
#        [3456.25      ,  121.15000153,  958.95001221, 2724.35009766,
#         2535.30004883],
#        [3364.39990234,  123.30000305,  951.79998779, 2700.55004883,
#         2539.        ],
#        [3378.64990234,  123.75      ,  942.54998779, 2714.55004883,
#         2552.25      ],
#        [3373.69995117,  123.94999695,  943.70001221, 2685.10009766,
#         2521.80004883],
#        [3280.39990234,  125.09999847,  959.45001221, 2673.39990234,
#         2521.60009766],
#        [3306.39990234,  125.5       ,  939.5       , 2675.94995117,
#         2477.44995117],
#        [3274.85009766,  121.69999695,  903.40002441, 2700.60009766,
#         2477.85009766],
#        [3155.14990234,  120.34999847,  922.        , 2640.35009766,
#         2377.89990234],
#        [3147.10009766,  121.44999695,  915.95001221, 2589.85009766,
#         2373.25      ],
#        [3116.94995117,  122.69999695,  888.09997559, 2460.89990234,
#         2338.10009766],
#        [3110.85009766,  124.09999847,  899.75      , 2475.80004883,
#         2335.85009766],
#        [3152.25      ,  125.19999695,  908.09997559, 2456.5       ,
#         2386.60009766],
#        [3196.25      ,  121.75      ,  904.04998779, 2472.85009766,
#         2378.69995117],
#        [3197.69995117,  124.44999695,  913.54998779, 2522.89990234,
#         2383.55004883],
#        [3203.        ,  124.65000153,  900.        , 2503.19995117,
#         2352.75      ],
#        [3236.64990234,  124.15000153,  872.20001221, 2481.80004883,
#         2331.30004883],
#        [3174.69995117,  122.90000153,  804.70001221, 2435.5       ,
#         2317.10009766],
#        [3216.35009766,  121.34999847,  787.59997559, 2415.35009766,
#         2356.05004883],
#        [3228.35009766,  121.05000305,  800.95001221, 2480.60009766,
#         2383.5       ],
#        [3238.75      ,  119.94999695,  806.34997559, 2489.05004883,
#         2381.05004883],
#        [3216.30004883,  122.05000305,  798.09997559, 2432.25      ,
#         2376.39990234],
#        [3143.44995117,  116.55000305,  761.34997559, 2388.55004883,
#         2338.55004883],
#        [3264.60009766,  118.75      ,  764.20001221, 2448.10009766,
#         2417.94995117],
#        [3252.85009766,  121.5       ,  777.40002441, 2422.69995117,
#         2412.94995117],
#        [3265.85009766,  121.40000153,  772.29998779, 2446.80004883,
#         2443.5       ],
#        [3258.44995117,  121.15000153,  767.75      , 2430.69995117,
#         2424.39990234],
#        [3251.64990234,  119.19999695,  760.75      , 2426.30004883,
#         2399.89990234],
#        [3227.14990234,  117.09999847,  752.20001221, 2382.69995117,
#         2389.        ],
#        [3237.19995117,  117.15000153,  756.        , 2415.60009766,
#         2374.05004883],
#        [3069.05004883,  110.        ,  713.20001221, 2310.75      ,
#         2255.75      ],
#        [3119.19995117,  112.34999847,  741.95001221, 2369.05004883,
#         2283.94995117],
#        [3174.64990234,  115.        ,  745.84997559, 2402.94995117,
#         2359.55004883],
#        [3028.94995117,  112.25      ,  728.15002441, 2397.80004883,
#         2398.55004883],
#        [2871.89990234,  114.65000153,  719.5       , 2338.64990234,
#         2378.30004883],
#        [2738.14990234,  113.25      ,  704.34997559, 2260.94995117,
#         2325.55004883],
#        [2708.44995117,  112.25      ,  700.79998779, 2164.64990234,
#         2239.55004883],
#        [2723.39990234,  117.05000305,  708.40002441, 2180.85009766,
#         2235.5       ],
#        [2874.94995117,  116.94999695,  739.40002441, 2237.60009766,
#         2354.10009766],
#        [2912.80004883,  120.94999695,  739.54998779, 2349.89990234,
#         2392.25      ],
#        [2932.        ,  123.69999695,  747.90002441, 2338.14990234,
#         2399.14990234],
#        [2962.80004883,  120.80000305,  745.20001221, 2344.69995117,
#         2418.85009766],
#        [2987.14990234,  119.        ,  737.95001221, 2370.55004883,
#         2363.44995117],
#        [3042.        ,  121.94999695,  749.59997559, 2462.89990234,
#         2403.35009766],
#        [3136.60009766,  121.34999847,  765.34997559, 2510.39990234,
#         2481.69995117],
#        [3045.75      ,  118.        ,  755.15002441, 2485.25      ,
#         2467.39990234],
#        [3051.14990234,  120.65000153,  757.25      , 2450.35009766,
#         2531.14990234],
#        [3011.80004883,  121.19999695,  747.20001221, 2428.60009766,
#         2546.30004883]])

# %%
x_pred = x_scale.transform(df_pred)

print(x_pred.shape)
# Out:
# (100, 5)

# %%
next_day_price = load_model.predict(x_pred.reshape(-1, x_pred.shape[0], x_pred.shape[1]))

# %%
print(y_scale.inverse_transform(next_day_price))
# Out:
# [[3033.3398    116.084206  749.45996  2386.426    2505.0662  ]]

# %% [markdown]
# # Helper functions

# %% [markdown]
# ## Calculate expected returns, annual volatility and Sharpe ratio of portfolio

# %%
def get_port_stats(returns, weights, cov_matrix):
  # EXPECTED ANNUAL RETURN (252 is the approx number of trading days in a year)
  annual_returns = returns.mean() * 252
  # find expected portfolio returns
  expected_return = np.sum(weights.T.values * annual_returns.values)

  # ANNUAL VOLATILITY
  # find annual volatility of portfolio
  volatility = np.sqrt(np.dot(weights.T,np.dot(cov_matrix * 252,weights)))

  # SHARPE RATIO (Assuming 0 risk free return. Alternative is to use a value of 0.02)
  sharpe_ratio = expected_return / volatility

  print(f"Expected Returns: {(expected_return * 100).round(decimals = 2)}%")
  print(f"Annual Volatility: {(volatility * 100).round(decimals = 2)[0][0]}%")
  print(f"Sharpe Ratio: {sharpe_ratio.round(decimals = 2)[0][0]}")

  return (expected_return * 100).round(decimals = 2), (volatility * 100).round(decimals = 2)[0][0], sharpe_ratio.round(decimals = 2)[0][0]

# %% [markdown]
# ## Calculate CVaR of each asset

# %%
def get_CVaR(pct_change):

  cvar_list = []

  for i in range(port_len):
    print(f'The worst case loss for {tickers[i]} is {round(rp.RiskFunctions.CVaR_Hist(pct_change.iloc[:, i]) * 100, 2)}% and we can conclude this with a confidence of 95%.')
    cvar_list.append(rp.RiskFunctions.CVaR_Hist(pct_change.iloc[:, i]))

  cvar_df = pd.DataFrame(cvar_list, index = tickers);

  return cvar_df

# %% [markdown]
# ## Calculating reduction factor

# %%
def get_reduction_factor(cvar_list, max_range = 0.25):

  scaler = MinMaxScaler(feature_range=(0, max_range))

  scaled_data = scaler.fit_transform(np.array(cvar_list).reshape(-1,1))

  f = lambda x: 1 - x

  return f(scaled_data)

# %% [markdown]
# ## Softmax function

# %%
def softmax(x):
  """Compute softmax values for each sets of scores in x."""
  return np.exp(x) / np.sum(np.exp(x), axis=0)

# %% [markdown]
# # Calculating Piotroski F-Score
#
# The Piotroski Score is calculated based on nine criteria that can be grouped into three different categories:
# 1. **Category 1: Profitability**
# > - Net Income > 0 (Score +1)
# > - Return on Assets (ROA) > 0 (Score +1)
# > - Cash flow from operating activities (CFO) > 0 (Score +1)
# > - CFO > Net Income (Score +1)
# 1. **Category 2: Leverage, Liquidity, and Source of Funds**
# > - Long Term Debt [Current Year] < Long Term Debt [Previous Year] (Score +1)
# > - Current Ratio [Current Year] > Current Ratio [Previous Year] (Score +1)
# > - No new shares issued in the last year (Score +1)
# 1. **Category 3: Operating Efficiency**
# > - Gross Margin [Current Year] > Gross Margin [Previous Year] (Score +1)
# > - Asset Turnover Ratio [Current Year] > Asset Turnover Ratio [Previous Year] (Score +1)
# ---
# With each criterion met, a score of 1 will be merited.
#
# ```
# Good or high score = 7, 8, 9
# Bad or low score = 0, 1, 2, 3
# ```
#
# Reference - https://www.investopedia.com/terms/p/piotroski-score.asp

# %% [markdown]
# ## Helper functions for calculating Piotroski Score

# %%
# Getting the net income of an asset
def get_net_income(income_df):
  return float(income_df.loc['Net Income'][0])

# Get return on assets
"""The term return on assets (ROA) refers to a financial ratio that indicates how profitable 
a company is in relation to its total assets. Corporate management, analysts, and investors 
can use ROA to determine how efficiently a company uses its assets to generate a profit."""
def get_roa(balance_df, income_df):
  current = float(balance_df.loc['Total Assets'][0])
  previous = float(balance_df.loc['Total Assets'][1])

  av_assets=(current+previous)/2

  return get_net_income(income_df)/av_assets

# Get operating cash flow
def get_ocf(cash_df):
  return float(cash_df.loc['Total Cash From Operating Activities'][0])

# Get long term debt
def get_ltdebt(balance_df):
  if 'Long Term Debt' in balance_df.index:
    current = float(balance_df.loc['Long Term Debt'][0])
    previous = float(balance_df.loc['Long Term Debt'][1])

    return previous-current

  return None

# Get current ratio
def get_current_ratio(balance_df):
  current_TCA = float(balance_df.loc['Total Current Assets'][0])
  previous_TCA = float(balance_df.loc['Total Current Assets'][1])
  current_TCL = float(balance_df.loc['Total Current Liabilities'][0])
  previous_TCL = float(balance_df.loc['Total Current Liabilities'][1])
  
  ratio1 = current_TCA/current_TCL
  ratio2 = previous_TCA/previous_TCL
  
  return ratio1-ratio2

# Get count of new shares if issued
def get_new_shares(balance_df):
  current = float(balance_df.loc['Common Stock'][0])
  previous = float(balance_df.loc['Common Stock'][1])
  
  return current-previous

# Get gross margin
def get_gross_margin(income_df):
  current = float(income_df.loc['Gross Profit'][0])/float(income_df.loc['Total Revenue'][0])
  previous = float(income_df.loc['Gross Profit'][1])/float(income_df.loc['Total Revenue'][1])

  return current-previous


# Get asset turnover ratio
def get_asset_turnover_ratio(income_df, balance_df):
  current = float(balance_df.loc['Total Assets'][0])
  prev_1 = float(balance_df.loc['Total Assets'][1])
  prev_2 = float(balance_df.loc['Total Assets'][2])
  
  av_assets1 = (current+prev_1)/2
  av_assets2 = (prev_1+prev_2)/2
  
  atr1 = float(income_df.loc['Total Revenue'][0])/av_assets1
  atr2 = float(income_df.loc['Total Revenue'][1])/av_assets2

  return atr1-atr2

# %%
def get_piotroski_score(income_df, balance_df, cash_df):
  score=0
  passed = []

  print(f"Net income - {get_net_income(income_df)}")
  
  if get_net_income(income_df)>0:
    passed.append("Net income")
    score+=1

  print(f'ROA - {get_roa(balance_df, income_df)}')
  
  if get_roa(balance_df, income_df)>0:
    passed.append("ROA")
    score+=1

  print(f"Operating Cash flow - {get_ocf(cash_df)}")
     
  if get_ocf(cash_df)>0:
    passed.append("CFO")
    score+=1

  print(f"Operating Cash flow > Net Income - {get_ocf(cash_df)>get_net_income(income_df)}")
      
  if get_ocf(cash_df)>get_net_income(income_df):
    passed.append("CFO > NI")
    score+=1

  print(f"Long term debt - {get_ltdebt(balance_df)}")

  if get_ltdebt(balance_df) is None:
    print("No data on long term debt!")

  elif get_ltdebt(balance_df)>0:
    passed.append("LTD")
    score+=1
  
  print(f"Current ratio - {get_current_ratio(balance_df)}")
      
  if get_current_ratio(balance_df)>0:
    passed.append("CR")
    score+=1

  print(f"New shares count - {get_new_shares(balance_df)}")
      
  if get_new_shares(balance_df)>0:
    passed.append("New shares")
    score+=1

  print(f"New shares count - {get_gross_margin(income_df)}")
      
  if get_gross_margin(income_df)>0:
    passed.append("GM")
    score+=1

  print((f"Asset turnover ratio - {get_asset_turnover_ratio(income_df, balance_df)}"))
      
  if get_asset_turnover_ratio(income_df, balance_df)>0:
    passed.append("ATR")
    score+=1

  print(f'Passed metrics - {passed}')
      
  return score

# %% [markdown]
# # Calculating RoE (Return on Equity)
#
# The Return on equity is a measure of the profitability of a business in relation to the equity.
#
# Because stock holders' equity is equal to a company's assets minus its debt, RoE is considered the return on net assets. RoE is considered a gauge of a corporation's profitability and how efficient it is in generating profits.
#
# Negative RoE -  When a company incurs a loss, there is no net income and so the return on equity is negative.
#
# Reference - https://towardsdatascience.com/calculating-return-on-equity-with-python-1ea583cd53bd

# %%
def get_roe(income_df, balance_df):
  ni = float(income_df.loc['Net Income'][0])

  eq1 = float(balance_df.loc["Total Stockholder Equity"][0])
  eq2 = float(balance_df.loc["Total Stockholder Equity"][1])

  avg_eq = (eq1+eq2)/2
  roe = ni/avg_eq

  return roe

# %% [markdown]
# # Calculating RoCE (Return on Capital Employed)
#
# RoCE can be especially useful when comparing the performance of companies in capital-intensive sectors, such as utilities and telecoms. This is because, unlike other fundamentals such as return on equity (RoE), which only analyzes profitability related to a company’s shareholders’ equity, RoCE considers debt and equity. This can help neutralize financial performance analysis for companies with significant debt.
#
# Ultimately, the calculation of RoCE tells you the amount of profit a company is generating per \$1 of capital employed. The more profit per \$1 a company can generate, the better. Thus, a higher RoCE indicates stronger profitability across company comparisons.
#
# Reference - https://www.investopedia.com/terms/r/roce.asp

# %%
def get_roce(income_df,balance_df):
  # n = float(income_df.loc["Ebit"][0])
  n = float(income_df.loc["Operating Income"][0])
  d = float(balance_df.loc["Total Assets"][0])-float(balance_df.loc["Total Current Liabilities"][0])

  roce = n/d;

  return roce

# %% [markdown]
# # Calculating P/E Ratio
#
#
# The price-to-earnings (P/E) ratio relates a company's share price to its earnings per share.
#
# A high P/E ratio could mean that a company's stock is overvalued, or else that investors are expecting high growth rates in the future.
#
# Companies that have no earnings or that are losing money do not have a P/E ratio because there is nothing to put in the denominator.
#
# As far as Nifty is concerned, it has traded in a PE range of 10 to 30 historically. Average PE of Nifty in the last 20 years was around 20. So **PEs below 20 may provide good investment opportunities; lower the PE below 20, more attractive the investment potential.**
#
# Reference - https://www.miraeassetmf.co.in/knowledge-center/what-is-pe-ratio

# %%
def get_pe(info):
  pe = float(info["currentPrice"]) / float(info["trailingEps"])
  
  return pe

# %% [markdown]
# # Calculating PEG ratio [Not important]
#
# The price/earnings to growth ratio (PEG ratio) is a stock's price-to-earnings (P/E) ratio divided by the growth rate of its earnings for a specified time period. The PEG ratio is used to determine a stock's value while also factoring in the company's expected earnings growth, and it is thought to provide a more complete picture than the more standard P/E ratio.

# %%
def get_peg(info):
  
  if info["pegRatio"]:
    peg = info["pegRatio"]
    return peg

  return None

# %% [markdown]
# # Calculating Debt-to-Asset Ratio
#
# Debt-to-Asset Ratio is total debt divided by total assets.
#
# The debt to asset ratio is commonly used by analysts, investors, and creditors to determine the overall risk of a company. Companies with a higher ratio are more leveraged and, hence, riskier to invest in and provide loans to. If the ratio steadily increases, it could indicate a default at some point in the future.
#
# - A ratio equal to one (=1) means that the company owns the same amount of liabilities as its assets. It indicates that the company is highly leveraged.
# - A ratio greater than one (>1) means the company owns more liabilities than it does assets. It indicates that the company is extremely leveraged and highly risky to invest in or lend to.
# - A ratio of less than one (<1) means the company owns more assets than liabilities and can meet its obligations by selling its assets if needed. The lower the debt to asset ratio, the less risky the company.

# %%
def get_debt_to_assets_ratio(balance_df, info):
  if info["totalDebt"]:
    da = float(info["totalDebt"]) / float(balance_df.loc["Total Assets"][0])
    return da

  elif 'Short Long Term Debt' in balance_df.index:
    da = float(balance_df.loc["Short Long Term Debt"][0]) / float(balance_df.loc["Total Assets"][0])
    return da

  elif 'Long Term Debt' in balance_df.index:
    da = float(balance_df.loc["Long Term Debt"][0]) / float(balance_df.loc["Total Assets"][0])
    return da

  return 0

# %% [markdown]
# # Calculating CAGR (Compound Annual Growth Rate)
#
# The compound annual growth rate (CAGR) is the rate of return (RoR) that would be required for an investment to grow from its beginning balance to its ending balance, assuming the profits were reinvested at the end of each period of the investment's life span.

# %%
def get_cagr(ticker):
  return round(ffn.core.calc_cagr(df[ticker]) * 100, 2)

# %% [markdown]
# # Checking if current assets are 1.5 times the current liabilities

# %%
def assets_vs_liabilities(balance_df):
  if balance_df.loc["Total Current Assets"][0] > (balance_df.loc["Total Current Liabilities"][0] * 1.5):
    return True

  return False

# %% [markdown]
# # Fundamentals analyser

# %%
def calc_piotroski_score(ticker, income_df, balance_df, cash_df):

  ps = get_piotroski_score(income_df, balance_df, cash_df)
  print(f'Piotroski score for {ticker} is {ps}')

  return int(ps)

# %%
def calc_roe(ticker, income_df, balance_df):
  roe = get_roe(income_df, balance_df)
  print(f'RoE for {ticker} is {round(roe * 100, 2)}%')

  return round(roe * 100, 2)

# %%
def calc_roce(ticker, income_df, balance_df):
  roce = get_roce(income_df, balance_df)
  print(f'RoCE for {ticker} is {round(roce * 100, 2)}%')

  return round(roce * 100, 2)

# %%
def calc_pe(ticker, info):
  pe = get_pe(info)
  print(f'P/E ratio for {ticker} is {round(pe, 2)}')

  return round(pe, 2)

# %%
def calc_peg(ticker, info):
  peg = get_peg(info)

  if peg:
    print(f'PEG ratio for {ticker} is {peg}')
  else:
    print('PEG ratio not available!')

  return peg

# %%
def calc_debt_to_assets_ratio(ticker, balance_df, info):
  da = get_debt_to_assets_ratio(balance_df, info)
  print(f'Debt to asset ratio for {ticker} is {round(da, 2)}')

  return round(da, 2)

# %%
def calc_cagr(ticker):
  cagr = get_cagr(ticker)
  print(f'CAGR for {ticker} is {cagr}%')

  return cagr

# %%
def check_if_assets_are_greater_than_liabilities(ticker, balance_df):
  is_greater = assets_vs_liabilities(balance_df)

  if is_greater is True:
    print(f'Current assets of {ticker} are 1.5 times it\'s current liabilities. - GOOD ASSET!')
    return "Yes"
  else:
    print(f'Current assets of {ticker} aren\'t 1.5 times it\'s current liabilities. - NOT SO GOOD ASSET!')
    return "No"

# %%
fundamentals_analyser_dict = dict()

# %%
def fundamentals_analyser(tickers):
  # Analysing fundamentals of asset using various methods
  for t in tickers:
    # Getting balance sheet, income statement and financials of the asset
    income_df = extra_info_tickers.tickers[t].financials.dropna()
    balance_df = extra_info_tickers.tickers[t].balance_sheet.dropna()
    cash_df = extra_info_tickers.tickers[t].cashflow.dropna()

    fundamentals_analyser_dict[t] = []

    print("PIOTROSKI SCORE")
    fundamentals_analyser_dict[t].append(calc_piotroski_score(t, income_df, balance_df, cash_df))
    print("--------------------------")
    print("CAGR")
    fundamentals_analyser_dict[t].append(calc_cagr(t))
    print("--------------------------")
    print("RoE")
    fundamentals_analyser_dict[t].append(calc_roe(t, income_df, balance_df))
    print("--------------------------")
    print("RoCE")
    fundamentals_analyser_dict[t].append(calc_roce(t, income_df, balance_df))
    print("--------------------------")
    print("P/E ratio")
    fundamentals_analyser_dict[t].append(calc_pe(t, extra_info_tickers.tickers[t].info))
    # PEG RATIO NOT AVAILABLE FOR MOST ASSETS
    # print("--------------------------")
    # print("PEG ratio") 
    # calc_peg(t, extra_info_tickers.tickers[t].info)
    print("--------------------------")
    print("P/B ratio")
    fundamentals_analyser_dict[t].append(round(extra_info_tickers.tickers[t].info["priceToBook"], 2))
    print(f'P/B ratio for {t} is {round(extra_info_tickers.tickers[t].info["priceToBook"], 2)}')
    print("--------------------------")
    print(f'Analyst recommendation - {extra_info_tickers.tickers[t].info["recommendationKey"]}')
    fundamentals_analyser_dict[t].append(extra_info_tickers.tickers[t].info["recommendationKey"])
    print("--------------------------")
    print("Debt to asset ratio")
    fundamentals_analyser_dict[t].append(calc_debt_to_assets_ratio(t, balance_df, extra_info_tickers.tickers[t].info))
    print("--------------------------")
    fundamentals_analyser_dict[t].append(check_if_assets_are_greater_than_liabilities(t, balance_df))
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~")

# %%
fundamentals_analyser(tickers)
# Out:
# PIOTROSKI SCORE
# Net income - 49943000000.0
# ROA - 0.07262986407440841
# Operating Cash flow - 75557800000.0
# Operating Cash flow > Net Income - True
# Long term debt - -67542000000.0
# Current ratio - -0.1474520264401502
# New shares count - 0.0
# New shares count - 0.010052550417347206
# Asset turnover ratio - -0.010180384769108847
# Passed metrics - ['Net income', 'ROA', 'CFO', 'CFO > NI', 'GM']
# Piotroski score for ADANIPORTS.NS is 5
# --------------------------
# CAGR
# CAGR for ADANIPORTS.NS is 18.99%
# --------------------------
# RoE
# RoE for ADANIPORTS.NS is 17.86%
# --------------------------
# RoCE
# RoCE for ADANIPORTS.NS is 8.67%
# --------------------------
# P/E ratio
# P/E ratio for ADANIPORTS.NS is 34.0
# --------------------------
# P/B ratio
# P/B ratio for ADANIPORTS.NS is 5.36
# --------------------------
# Analyst recommendation - buy
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for ADANIPORTS.NS is 0.61
# --------------------------
# Current assets of ADANIPORTS.NS are 1.5 times it's current liabilities. - GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# PIOTROSKI SCORE
# Net income - 31392900000.0
# ROA - 0.1719010228507581
# Operating Cash flow - 36833500000.0
# Operating Cash flow > Net Income - True
# Long term debt - 41000000.0
# Current ratio - 0.2990427388304231
# New shares count - 0.0
# New shares count - 0.005308145153408772
# Asset turnover ratio - -0.060051598247782056
# Passed metrics - ['Net income', 'ROA', 'CFO', 'CFO > NI', 'LTD', 'CR', 'GM']
# Piotroski score for ASIANPAINT.NS is 7
# --------------------------
# CAGR
# CAGR for ASIANPAINT.NS is 20.94%
# --------------------------
# RoE
# RoE for ASIANPAINT.NS is 27.37%
# --------------------------
# RoCE
# RoCE for ASIANPAINT.NS is 28.14%
# --------------------------
# P/E ratio
# P/E ratio for ASIANPAINT.NS is 95.4
# --------------------------
# P/B ratio
# P/B ratio for ASIANPAINT.NS is 23.15
# --------------------------
# Analyst recommendation - hold
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for ASIANPAINT.NS is 0.07
# --------------------------
# Current assets of ASIANPAINT.NS are 1.5 times it's current liabilities. - GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# PIOTROSKI SCORE
# Net income - -150835000000.0
# ROA - -0.04268068728257849
# Operating Cash flow - 482050000000.0
# Operating Cash flow > Net Income - True
# Long term debt - -194811000000.0
# Current ratio - -0.0924333774127371
# New shares count - 182000000.0
# New shares count - 0.028752168209470352
# Asset turnover ratio - 0.015388867587421307
# Passed metrics - ['CFO', 'CFO > NI', 'New shares', 'GM', 'ATR']
# Piotroski score for BHARTIARTL.NS is 5
# --------------------------
# CAGR
# CAGR for BHARTIARTL.NS is 17.12%
# --------------------------
# RoE
# RoE for BHARTIARTL.NS is -22.17%
# --------------------------
# RoCE
# RoCE for BHARTIARTL.NS is 7.09%
# --------------------------
# P/E ratio
# P/E ratio for BHARTIARTL.NS is 129.96
# --------------------------
# P/B ratio
# P/B ratio for BHARTIARTL.NS is 6.34
# --------------------------
# Analyst recommendation - none
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for BHARTIARTL.NS is 0.49
# --------------------------
# Current assets of BHARTIARTL.NS aren't 1.5 times it's current liabilities. - NOT SO GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# PIOTROSKI SCORE
# Net income - 24048700000.0
# ROA - 0.09853107020564607
# Operating Cash flow - 37552000000.0
# Operating Cash flow > Net Income - True
# Long term debt - 11665300000.0
# Current ratio - 0.20659744507661504
# New shares count - 400000.0
# New shares count - -0.032609229957838104
# Asset turnover ratio - 0.06617309606477317
# Passed metrics - ['Net income', 'ROA', 'CFO', 'CFO > NI', 'LTD', 'CR', 'New shares', 'ATR']
# Piotroski score for CIPLA.NS is 8
# --------------------------
# CAGR
# CAGR for CIPLA.NS is 11.14%
# --------------------------
# RoE
# RoE for CIPLA.NS is 14.11%
# --------------------------
# RoCE
# RoCE for CIPLA.NS is 15.88%
# --------------------------
# P/E ratio
# P/E ratio for CIPLA.NS is 29.39
# --------------------------
# P/B ratio
# P/B ratio for CIPLA.NS is 3.88
# --------------------------
# Analyst recommendation - buy
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for CIPLA.NS is 0.05
# --------------------------
# Current assets of CIPLA.NS are 1.5 times it's current liabilities. - GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# PIOTROSKI SCORE
# Net income - 380527500000.0
# ROA - 0.019402586573683156
# Operating Cash flow - -2362417200000.0
# Operating Cash flow > Net Income - False
# Long term debt - -938956713000.0
# Current ratio - -0.004679957368750515
# New shares count - 32724000.0
# New shares count - 0.0
# Asset turnover ratio - 0.0004650489770138891
# Passed metrics - ['Net income', 'ROA', 'New shares', 'ATR']
# Piotroski score for HDFCBANK.NS is 4
# --------------------------
# CAGR
# CAGR for HDFCBANK.NS is 11.43%
# --------------------------
# RoE
# RoE for HDFCBANK.NS is 16.65%
# --------------------------
# RoCE
# RoCE for HDFCBANK.NS is 9.01%
# --------------------------
# P/E ratio
# P/E ratio for HDFCBANK.NS is 19.29
# --------------------------
# P/B ratio
# P/B ratio for HDFCBANK.NS is 2.96
# --------------------------
# Analyst recommendation - buy
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for HDFCBANK.NS is 0.11
# --------------------------
# Current assets of HDFCBANK.NS aren't 1.5 times it's current liabilities. - NOT SO GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# PIOTROSKI SCORE
# Net income - 251101000000.0
# ROA - 0.015097237495679466
# Operating Cash flow - -733143400000.0
# Operating Cash flow > Net Income - False
# Long term debt - -219215300000.0
# Current ratio - 0.004060724258900389
# New shares count - 67715000.0
# New shares count - 0.0
# Asset turnover ratio - -0.0009220222357495533
# Passed metrics - ['Net income', 'ROA', 'CR', 'New shares']
# Piotroski score for ICICIBANK.NS is 4
# --------------------------
# CAGR
# CAGR for ICICIBANK.NS is 21.19%
# --------------------------
# RoE
# RoE for ICICIBANK.NS is 14.79%
# --------------------------
# RoCE
# RoCE for ICICIBANK.NS is 5.18%
# --------------------------
# P/E ratio
# P/E ratio for ICICIBANK.NS is 20.29
# --------------------------
# P/B ratio
# P/B ratio for ICICIBANK.NS is 2.75
# --------------------------
# Analyst recommendation - strong_buy
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for ICICIBANK.NS is 0.09
# --------------------------
# Current assets of ICICIBANK.NS aren't 1.5 times it's current liabilities. - NOT SO GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# PIOTROSKI SCORE
# Net income - 2613000000.0
# ROA - 0.19294812626915267
# Operating Cash flow - 3258000000.0
# Operating Cash flow > Net Income - True
# Long term debt - None
# No data on long term debt!
# Current ratio - -0.07085006880880762
# New shares count - 0.0
# New shares count - 0.020783865496644793
# Asset turnover ratio - -0.041388499410279334
# Passed metrics - ['Net income', 'ROA', 'CFO', 'CFO > NI', 'GM']
# Piotroski score for INFY.NS is 5
# --------------------------
# CAGR
# CAGR for INFY.NS is 26.73%
# --------------------------
# RoE
# RoE for INFY.NS is 27.38%
# --------------------------
# RoCE
# RoCE for INFY.NS is 28.78%
# --------------------------
# P/E ratio
# P/E ratio for INFY.NS is 28.8
# --------------------------
# P/B ratio
# P/B ratio for INFY.NS is 650.72
# --------------------------
# Analyst recommendation - buy
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for INFY.NS is 0.05
# --------------------------
# Current assets of INFY.NS are 1.5 times it's current liabilities. - GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# PIOTROSKI SCORE
# Net income - 12165300000.0
# ROA - 0.050068845537202006
# Operating Cash flow - 18217600000.0
# Operating Cash flow > Net Income - True
# Long term debt - 17771600000.0
# Current ratio - -0.012851540520726124
# New shares count - 1400000.0
# New shares count - -0.0030452902065339904
# Asset turnover ratio - 0.043151873269863805
# Passed metrics - ['Net income', 'ROA', 'CFO', 'CFO > NI', 'LTD', 'New shares', 'ATR']
# Piotroski score for LUPIN.NS is 7
# --------------------------
# CAGR
# CAGR for LUPIN.NS is -10.78%
# --------------------------
# RoE
# RoE for LUPIN.NS is 9.24%
# --------------------------
# RoCE
# RoCE for LUPIN.NS is 11.53%
# --------------------------
# P/E ratio
# P/E ratio for LUPIN.NS is -49.99
# --------------------------
# P/B ratio
# P/B ratio for LUPIN.NS is 2.75
# --------------------------
# Analyst recommendation - hold
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for LUPIN.NS is 0.25
# --------------------------
# Current assets of LUPIN.NS are 1.5 times it's current liabilities. - GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# PIOTROSKI SCORE
# Net income - 491280000000.0
# ROA - 0.03950582338577805
# Operating Cash flow - 261850000000.0
# Operating Cash flow > Net Income - False
# Long term debt - 339480000000.0
# Current ratio - 0.7184003913882996
# New shares count - 1060000000.0
# New shares count - 0.05435054415574647
# Asset turnover ratio - -0.17567736162306885
# Passed metrics - ['Net income', 'ROA', 'CFO', 'LTD', 'CR', 'New shares', 'GM']
# Piotroski score for RELIANCE.NS is 7
# --------------------------
# CAGR
# CAGR for RELIANCE.NS is 32.02%
# --------------------------
# RoE
# RoE for RELIANCE.NS is 8.55%
# --------------------------
# RoCE
# RoCE for RELIANCE.NS is 5.13%
# --------------------------
# P/E ratio
# P/E ratio for RELIANCE.NS is 33.02
# --------------------------
# P/B ratio
# P/B ratio for RELIANCE.NS is 2.31
# --------------------------
# Analyst recommendation - buy
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for RELIANCE.NS is 0.2
# --------------------------
# Current assets of RELIANCE.NS aren't 1.5 times it's current liabilities. - NOT SO GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# PIOTROSKI SCORE
# Net income - 324300000000.0
# ROA - 0.25773072979996664
# Operating Cash flow - 388020000000.0
# Operating Cash flow > Net Income - True
# Long term debt - None
# No data on long term debt!
# Current ratio - -0.4279520193093891
# New shares count - -50000000.0
# New shares count - -0.008362353261412936
# Asset turnover ratio - -0.026204529518864206
# Passed metrics - ['Net income', 'ROA', 'CFO', 'CFO > NI']
# Piotroski score for TCS.NS is 4
# --------------------------
# CAGR
# CAGR for TCS.NS is 24.03%
# --------------------------
# RoE
# RoE for TCS.NS is 38.03%
# --------------------------
# RoCE
# RoCE for TCS.NS is 43.98%
# --------------------------
# P/E ratio
# P/E ratio for TCS.NS is 34.85
# --------------------------
# P/B ratio
# P/B ratio for TCS.NS is 13.1
# --------------------------
# Analyst recommendation - buy
# --------------------------
# Debt to asset ratio
# Debt to asset ratio for TCS.NS is 0.06
# --------------------------
# Current assets of TCS.NS are 1.5 times it's current liabilities. - GOOD ASSET!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## Converting fundamentals into table format for easier reading

# %%
fundamentals_df = pd.DataFrame(fundamentals_analyser_dict, index =['Piotroski Score', 
                                             'CAGR (in %)', 
                                             'RoE (in %)', 
                                             'RoCE (in %)',
                                             'P/E ratio',
                                             'P/B ratio',
                                             'Analyst recommendation',
                                             'Debt to asset ratio',
                                             'Is assets 1.5 times it\'s current liabilities?']) 

fundamentals_df
# Out:
#                                               ADANIPORTS.NS ASIANPAINT.NS  \
# Piotroski Score                                           5             7
# CAGR (in %)                                           18.99         20.94
# RoE (in %)                                            17.86         27.37
# RoCE (in %)                                            8.67         28.14
# P/E ratio                                              34.0          95.4
# P/B ratio                                              5.36         23.15
# Analyst recommendation                                  buy          hold
# Debt to asset ratio                                    0.61          0.07
# Is assets 1.5 times it's current liabilities?           Yes           Yes
#
#                                               BHARTIARTL.NS CIPLA.NS  \
# Piotroski Score                                           5        8
# CAGR (in %)                                           17.12    11.14
# RoE (in %)                                           -22.17    14.11
# RoCE (in %)                                            7.09    15.88
# P/E ratio                                            129.96    29.39
# P/B ratio                                              6.34     3.88
# Analyst recommendation                                 none      buy
# Debt to asset ratio                                    0.49     0.05
# Is assets 1.5 times it's current liabilities?            No      Yes
#
#                                               HDFCBANK.NS ICICIBANK.NS  \
# Piotroski Score                                         4            4
# CAGR (in %)                                         11.43        21.19
# RoE (in %)                                          16.65        14.79
# RoCE (in %)                                          9.01         5.18
# P/E ratio                                           19.29        20.29
# P/B ratio                                            2.96         2.75
# Analyst recommendation                                buy   strong_buy
# Debt to asset ratio                                  0.11         0.09
# Is assets 1.5 times it's current liabilities?          No           No
#
#                                               INFY.NS LUPIN.NS RELIANCE.NS  \
# Piotroski Score                                     5        7           7
# CAGR (in %)                                     26.73   -10.78       32.02
# RoE (in %)                                      27.38     9.24        8.55
# RoCE (in %)                                     28.78    11.53        5.13
# P/E ratio                                        28.8   -49.99       33.02
# P/B ratio                                      650.72     2.75        2.31
# Analyst recommendation                            buy     hold         buy
# Debt to asset ratio                              0.05     0.25         0.2
# Is assets 1.5 times it's current liabilities?     Yes      Yes          No
#
#                                               TCS.NS
# Piotroski Score                                    4
# CAGR (in %)                                    24.03
# RoE (in %)                                     38.03
# RoCE (in %)                                    43.98
# P/E ratio                                      34.85
# P/B ratio                                       13.1
# Analyst recommendation                           buy
# Debt to asset ratio                             0.06
# Is assets 1.5 times it's current liabilities?    Yes

# %% [markdown]
# ## Setting score for each asset

# %%
def get_relative_score_for_category(category, sort_order="desc"):
  # Sorting category from highest to lowest and calculating score based on index
  c_list = category.tolist()

  if sort_order is "desc":
    c_list.sort(reverse=True)
  else:
    c_list.sort()
  
  score_dict_with_tickers = dict()

  for i in range(port_len):
    if c_list[i] not in score_dict_with_tickers:
      score_dict_with_tickers[c_list[i]] = round((port_len - i)/port_len, 2)

  return score_dict_with_tickers

# %%
def set_score(fundamentals_df):

  score_dict = dict()

  rel_cagr_score_dict = get_relative_score_for_category(fundamentals_df.loc["CAGR (in %)", :])
  print(rel_cagr_score_dict)

  rel_roe_score_dict = get_relative_score_for_category(fundamentals_df.loc["RoE (in %)", :])
  print(rel_roe_score_dict)

  rel_roce_score_dict = get_relative_score_for_category(fundamentals_df.loc["RoCE (in %)", :])
  print(rel_roce_score_dict)

  rel_pe_score_dict = get_relative_score_for_category(fundamentals_df.loc["P/E ratio", :], "asc")
  print(rel_pe_score_dict)

  # Calculating overall score
  for t in tickers:
    ticker_score = 0
    ticker_analysis = fundamentals_df.loc[:, t].tolist()

    # Checking if Piotroski score is 7,8,9 or 10
    if ticker_analysis[0] > 6:
      ticker_score += (ticker_analysis[0] - 6)
    
    # Adding relative CAGR score to total asset score
    ticker_score += rel_cagr_score_dict[ticker_analysis[1]]

    # Adding relative RoE score to total asset score
    ticker_score += rel_roe_score_dict[ticker_analysis[2]]

    # Checking if RoE is greater than or equal to 20%
    if ticker_analysis[2] >= 20:
      ticker_score += 1

    # Adding relative RoCE score to total asset score
    ticker_score += rel_roce_score_dict[ticker_analysis[3]]

    # Checking if RoCE is greater than or equal to 20%
    if ticker_analysis[3] >= 20:
      ticker_score += 1

    # Adding relative P/E ratio score to total asset score
    ticker_score += rel_pe_score_dict[ticker_analysis[4]]

    # Checking if P/E ratio is less than 20
    if ticker_analysis[4] < 20:
      ticker_score += 1

    # Checking if P/B ratio is less than 3
    if ticker_analysis[5] < 3:
      ticker_score += 1

    # Checking analyst recommendation
    if ticker_analysis[6] is "buy":
      ticker_score += 1

    if ticker_analysis[6] is "strong_buy":
      ticker_score += 2

    # Checking if debt to asset ratio is less than 1.1
    if ticker_analysis[7] < 1.1:
      ticker_score += 1

    # Checking if the assets are 1.5 times the current liabilities
    if ticker_analysis[8] is "Yes":
      ticker_score += 1

    score_dict[t] = round(ticker_score, 2)

  return score_dict

score_dict = set_score(fundamentals_df)
sorted_score_dict = sorted(score_dict.items(), key=lambda x: x[1], reverse=True)

for s in sorted_score_dict:
  print(f'The fundamental analysis score for {s[0]} is {s[1]}')
# Out:
# {32.02: 1.0, 26.73: 0.9, 24.03: 0.8, 21.19: 0.7, 20.94: 0.6, 18.99: 0.5, 17.12: 0.4, 11.43: 0.3, 11.14: 0.2, -10.78: 0.1}
# {38.03: 1.0, 27.38: 0.9, 27.37: 0.8, 17.86: 0.7, 16.65: 0.6, 14.79: 0.5, 14.11: 0.4, 9.24: 0.3, 8.55: 0.2, -22.17: 0.1}
# {43.98: 1.0, 28.78: 0.9, 28.14: 0.8, 15.88: 0.7, 11.53: 0.6, 9.01: 0.5, 8.67: 0.4, 7.09: 0.3, 5.18: 0.2, 5.13: 0.1}
# {-49.99: 1.0, 19.29: 0.9, 20.29: 0.8, 28.8: 0.7, 29.39: 0.6, 33.02: 0.5, 34.0: 0.4, 34.85: 0.3, 95.4: 0.2, 129.96: 0.1}
# The fundamental analysis score for ASIANPAINT.NS is 7.4
# The fundamental analysis score for INFY.NS is 7.4
# The fundamental analysis score for TCS.NS is 7.1
# The fundamental analysis score for LUPIN.NS is 7.0
# The fundamental analysis score for CIPLA.NS is 5.9
# The fundamental analysis score for HDFCBANK.NS is 5.3
# The fundamental analysis score for RELIANCE.NS is 4.8
# The fundamental analysis score for ICICIBANK.NS is 4.2
# The fundamental analysis score for ADANIPORTS.NS is 4.0
# The fundamental analysis score for BHARTIARTL.NS is 1.9

# %% [markdown]
# # Calculating percentage change and covariance matrix

# %%
pct_change = df.pct_change().dropna()
cov = np.cov(pct_change.T)

# %%
# Covariance matrix representation

col_index = dict()

for i in range(port_len):
  col_index[i] = tickers[i]

pd_cov = pd.DataFrame(cov, index = [tickers])
pd_cov = pd_cov.rename(col_index, axis=1)
pd_cov
# Out:
#                ADANIPORTS.NS  ASIANPAINT.NS  BHARTIARTL.NS  CIPLA.NS  \
# ADANIPORTS.NS       0.000525       0.000118       0.000147  0.000079
# ASIANPAINT.NS       0.000118       0.000280       0.000093  0.000044
# BHARTIARTL.NS       0.000147       0.000093       0.000475  0.000081
# CIPLA.NS            0.000079       0.000044       0.000081  0.000326
# HDFCBANK.NS         0.000148       0.000098       0.000109  0.000034
# ICICIBANK.NS        0.000208       0.000118       0.000153  0.000064
# INFY.NS             0.000093       0.000070       0.000077  0.000056
# LUPIN.NS            0.000102       0.000037       0.000100  0.000191
# RELIANCE.NS         0.000166       0.000123       0.000121  0.000053
# TCS.NS              0.000081       0.000059       0.000059  0.000053
#
#                HDFCBANK.NS  ICICIBANK.NS   INFY.NS  LUPIN.NS  RELIANCE.NS  \
# ADANIPORTS.NS     0.000148      0.000208  0.000093  0.000102     0.000166
# ASIANPAINT.NS     0.000098      0.000118  0.000070  0.000037     0.000123
# BHARTIARTL.NS     0.000109      0.000153  0.000077  0.000100     0.000121
# CIPLA.NS          0.000034      0.000064  0.000056  0.000191     0.000053
# HDFCBANK.NS       0.000274      0.000207  0.000085  0.000041     0.000133
# ICICIBANK.NS      0.000207      0.000504  0.000105  0.000064     0.000167
# INFY.NS           0.000085      0.000105  0.000325  0.000060     0.000099
# LUPIN.NS          0.000041      0.000064  0.000060  0.000408     0.000078
# RELIANCE.NS       0.000133      0.000167  0.000099  0.000078     0.000389
# TCS.NS            0.000067      0.000081  0.000162  0.000057     0.000096
#
#                  TCS.NS
# ADANIPORTS.NS  0.000081
# ASIANPAINT.NS  0.000059
# BHARTIARTL.NS  0.000059
# CIPLA.NS       0.000053
# HDFCBANK.NS    0.000067
# ICICIBANK.NS   0.000081
# INFY.NS        0.000162
# LUPIN.NS       0.000057
# RELIANCE.NS    0.000096
# TCS.NS         0.000263

# %% [markdown]
# # Deep Learning Model for Portfolio Optimization [Method 1]

# %%
tf_port_data = tf.cast(tf.constant(df.iloc[1:]), float)

# %% [markdown]
# ## Custom sharpe loss function with reduction factor (based on CVaR risk measure)

# %%
def calc_reduction_factor(pct_change):
  # getting CVaR for each asset in the portfolio
  cvar_df = get_CVaR(pct_change)

  rf = get_reduction_factor(cvar_df[0])

  return rf

# %%
reduction_factor = calc_reduction_factor(pct_change)
tf_reduction_factor = tf.cast(tf.constant(reduction_factor), float)
tf_reduction_factor

# %%
def sharpe_loss_with_red_factor(_, y_pred):
  '''
  data.shape -> (lookback_period, port_len)
  y_pred.shape -> (None, port_len)
  '''
  new_weights = tf.multiply(tf_reduction_factor, tf.transpose(y_pred))

  # using softmax function formula
  new_y_pred = (tf.math.exp(new_weights) / tf.reduce_sum(tf.math.exp(new_weights), axis=0))

  # make all time-series start at 1 (Scaling down prices for fast multiplication)
  data = tf.divide(tf_port_data, tf_port_data[0])  
            
  # value of the portfolio after allocations applied
  portfolio_values = tf.reduce_sum(tf.multiply(data, tf.transpose(new_y_pred)), axis=1) 
  
  portfolio_returns = (portfolio_values[1:] - portfolio_values[:-1]) / portfolio_values[:-1]  # % change formula

  sharpe = K.mean(portfolio_returns) / K.std(portfolio_returns)

  # since we want to maximize Sharpe, while gradient descent minimizes the loss, 
  # we can negate Sharpe (the min of a negated function is its max)
  return -sharpe

# %% [markdown]
# ## Custom sharpe loss function without reduction factor

# %%
def sharpe_loss_without_red_factor(_, y_pred):
  '''
  data.shape -> (lookback_period, port_len)
  y_pred.shape -> (None, port_len)
  '''
  # make all time-series start at 1 (Scaling down prices for fast multiplication)
  data = tf.divide(tf_port_data, tf_port_data[0])  
            
  # value of the portfolio after allocations applied
  # tf.multiply is element wise multiplication
  portfolio_values = tf.reduce_sum(tf.multiply(data, y_pred), axis=1) 
  
  portfolio_returns = (portfolio_values[1:] - portfolio_values[:-1]) / portfolio_values[:-1]  # % change formula

  sharpe = K.mean(portfolio_returns) / K.std(portfolio_returns)

  # since we want to maximize Sharpe and gradient descent minimizes the loss, 
  # we can negate Sharpe (the min of a negated function is its max)
  return -sharpe

# %%
# Historical data with returns
df_w_ret = np.concatenate([df.values[1:], df.pct_change().dropna().values[0:]], axis=1)

df_w_ret.shape
# Out:
# (1235, 20)

# %%
try:
  del opt_model
except:
  print("Variable does not exist!")
# Out:
# Variable does not exist!

# %%
opt_model = Sequential([
            LSTM(64, input_shape=df_w_ret.shape),
            Flatten(),
            Dense(port_len, activation='softmax') 
        ])

# %%
# FOR TESTING:
# opt_model.compile(loss=sharpe_loss_without_red_factor, optimizer='adam', run_eagerly=True)
  
# FOR PRODUCTION:
opt_model.compile(loss=sharpe_loss_without_red_factor, optimizer='adam')

# %%
opt_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                21760
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 22,410
# Trainable params: 22,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
fit_predict_data = df_w_ret[np.newaxis,:]
fit_predict_data.shape
# Out:
# (1, 1235, 20)

# %%
with tf.device('/device:GPU:0'):
  opt_model.fit(fit_predict_data, np.zeros((1, port_len)), epochs=50, shuffle=False)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 10s 10s/step - loss: -0.0702
# Epoch 2/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0714
# Epoch 3/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0717
# Epoch 4/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0720
# Epoch 5/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0723
# Epoch 6/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0726
# Epoch 7/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0728
# Epoch 8/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0731
# Epoch 9/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0733
# Epoch 10/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0736
# Epoch 11/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0738
# Epoch 12/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0740
# Epoch 13/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0743
# Epoch 14/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0745
# Epoch 15/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0747
# Epoch 16/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0749
# Epoch 17/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0751
# Epoch 18/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0753
# Epoch 19/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0754
# Epoch 20/50
# 1/1 [==============================] - 6s 6s/step - loss: -0.0756
# Epoch 21/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0758
# Epoch 22/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0760
# Epoch 23/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0761
# Epoch 24/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0763
# Epoch 25/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0764
# Epoch 26/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0766
# Epoch 27/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0767
# Epoch 28/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0768
# Epoch 29/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0769
# Epoch 30/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0771
# Epoch 31/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0772
# Epoch 32/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0773
# Epoch 33/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0774
# Epoch 34/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0775
# Epoch 35/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0776
# Epoch 36/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0777
# Epoch 37/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0778
# Epoch 38/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0779
# Epoch 39/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0780
# Epoch 40/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0781
# Epoch 41/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0782
# Epoch 42/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0782
# Epoch 43/50
# 1/1 [==============================] - 5s 5s/step - loss: -0.0783
# Epoch 44/50
# 1/1 [==============================] - 5s 5s/step - loss: -0.0784
# Epoch 45/50
# 1/1 [==============================] - 13s 13s/step - loss: -0.0785
# Epoch 46/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0785
# Epoch 47/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0786
# Epoch 48/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0787
# Epoch 49/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0787
# Epoch 50/50
# 1/1 [==============================] - 4s 4s/step - loss: -0.0788

# %%
pred_weights_1 = opt_model.predict(fit_predict_data).T
pred_weights_1 = pd.DataFrame(pred_weights_1)
pred_weights_1
# Out:
#           0
# 0  0.049124
# 1  0.214993
# 2  0.100982
# 3  0.027422
# 4  0.015033
# 5  0.022913
# 6  0.170753
# 7  0.017167
# 8  0.134752
# 9  0.246862

# %% [markdown]
# ## Limiting weights to a threshold
#
# For each asset, weights are limited to a particular value so that risk is distributed among all assets.

# %%
def limit_weights(weights_df, threshold):
  return ffn.core.limit_weights(weights_df.to_dict()[0], threshold)

pred_weights_limited = limit_weights(pred_weights_1, 0.3)
pred_weights_limited = pd.DataFrame(pred_weights_limited)
pred_weights_limited
# Out:
#         0
# 0  0.0491
# 1  0.2150
# 2  0.1010
# 3  0.0274
# 4  0.0150
# 5  0.0229
# 6  0.1708
# 7  0.0172
# 8  0.1348
# 9  0.2469

# %%
erDLm1, cvDLm1, srDLm1 = get_port_stats(pct_change, pred_weights_limited, cov)
# Out:
# Expected Returns: 24.99%
# Annual Volatility: 18.18%
# Sharpe Ratio: 1.37

# %% [markdown]
# ## Replication of custom sharpe loss function

# %%
df.iloc[1:]
# Out:
#             APLAPOLLO.NS  BLUESTARCO.NS    BSOFT.NS   COFORGE.NS  \
# Date
# 2017-03-29    117.190002     651.099976   81.340538   425.549988
# 2017-03-30    118.489998     668.299988   81.216209   420.049988
# 2017-03-31    117.445000     692.400024   80.625664   435.600006
# 2017-04-03    120.254997     716.000000   80.812149   434.950012
# 2017-04-05    120.724998     694.200012   80.936478   433.149994
# ...                  ...            ...         ...          ...
# 2022-03-21    963.849976     978.750000  443.750000  4433.899902
# 2022-03-22    938.049988     984.750000  465.899994  4457.700195
# 2022-03-23    908.700012     995.049988  467.549988  4435.450195
# 2022-03-24    901.750000    1000.099976  480.100006  4478.950195
# 2022-03-28    901.700012     986.950012  458.250000  4374.899902
#
#             CUMMINSIND.NS  DHAMPURSUG.NS     SBIN.NS  TATAPOWER.NS  \
# Date
# 2017-03-29     932.950012     214.399994  288.450012     90.000000
# 2017-03-30     940.400024     219.949997  291.049988     89.900002
# 2017-03-31     949.450012     216.850006  293.399994     90.349998
# 2017-04-03     961.549988     224.149994  293.149994     89.199997
# 2017-04-05     968.750000     219.899994  297.350006     88.199997
# ...                   ...            ...         ...           ...
# 2022-03-21    1054.000000     532.799988  490.600006    227.949997
# 2022-03-22    1051.849976     533.799988  493.700012    231.399994
# 2022-03-23    1087.050049     533.599976  490.649994    234.300003
# 2022-03-24    1094.000000     545.549988  487.100006    239.500000
# 2022-03-28    1081.750000     527.299988  485.899994    238.850006
#
#                TRENT.NS      VTL.NS   ZENTEC.NS
# Date
# 2017-03-29   249.000000  258.630005   69.050003
# 2017-03-30   256.149994  262.320007   68.300003
# 2017-03-31   266.700012  262.529999   66.550003
# 2017-04-03   271.899994  271.769989   67.150002
# 2017-04-05   271.700012  270.950012   71.099998
# ...                 ...         ...         ...
# 2022-03-21  1279.599976  520.869995  197.100006
# 2022-03-22  1286.349976  513.090027  195.750000
# 2022-03-23  1300.250000  527.789978  195.750000
# 2022-03-24  1276.849976  539.950012  195.649994
# 2022-03-28  1264.800049  516.000000  198.500000
#
# [1234 rows x 11 columns]

# %%
df.iloc[1:] / df.iloc[1]
# Out:
#             APLAPOLLO.NS  BLUESTARCO.NS  BSOFT.NS  COFORGE.NS  CUMMINSIND.NS  \
# Date
# 2017-03-29      1.000000       1.000000  1.000000    1.000000       1.000000
# 2017-03-30      1.011093       1.026417  0.998472    0.987076       1.007985
# 2017-03-31      1.002176       1.063431  0.991211    1.023617       1.017686
# 2017-04-03      1.026154       1.099678  0.993504    1.022089       1.030655
# 2017-04-05      1.030165       1.066196  0.995032    1.017859       1.038373
# ...                  ...            ...       ...         ...            ...
# 2022-03-21      8.224677       1.503225  5.455459   10.419222       1.129750
# 2022-03-22      8.004522       1.512441  5.727771   10.475151       1.127445
# 2022-03-23      7.754075       1.528260  5.748056   10.422865       1.165175
# 2022-03-24      7.694769       1.536016  5.902346   10.525086       1.172624
# 2022-03-28      7.694342       1.515819  5.633722   10.280578       1.159494
#
#             DHAMPURSUG.NS   SBIN.NS  TATAPOWER.NS  TRENT.NS    VTL.NS  \
# Date
# 2017-03-29       1.000000  1.000000      1.000000  1.000000  1.000000
# 2017-03-30       1.025886  1.009014      0.998889  1.028715  1.014267
# 2017-03-31       1.011427  1.017161      1.003889  1.071084  1.015079
# 2017-04-03       1.045476  1.016294      0.991111  1.091968  1.050806
# 2017-04-05       1.025653  1.030855      0.980000  1.091165  1.047636
# ...                   ...       ...           ...       ...       ...
# 2022-03-21       2.485075  1.700815      2.532778  5.138956  2.013958
# 2022-03-22       2.489739  1.711562      2.571111  5.166064  1.983877
# 2022-03-23       2.488806  1.700988      2.603333  5.221888  2.040714
# 2022-03-24       2.544543  1.688681      2.661111  5.127912  2.087732
# 2022-03-28       2.459422  1.684521      2.653889  5.079518  1.995128
#
#             ZENTEC.NS
# Date
# 2017-03-29   1.000000
# 2017-03-30   0.989138
# 2017-03-31   0.963794
# 2017-04-03   0.972484
# 2017-04-05   1.029689
# ...               ...
# 2022-03-21   2.854453
# 2022-03-22   2.834902
# 2022-03-23   2.834902
# 2022-03-24   2.833454
# 2022-03-28   2.874728
#
# [1234 rows x 11 columns]

# %%
# using a sample set of equal weights for all assets in portfolio and replicating the custom loss function
# calculations
pd.DataFrame(np.multiply((df.iloc[1:] / df.iloc[1]).values, np.array([1 / port_len for x in range(port_len)])))
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.090909  0.090909  0.090909  0.090909  0.090909  0.090909  0.090909
# 1     0.091918  0.093311  0.090770  0.089734  0.091635  0.093262  0.091729
# 2     0.091107  0.096676  0.090110  0.093056  0.092517  0.091948  0.092469
# 3     0.093287  0.099971  0.090319  0.092917  0.093696  0.095043  0.092390
# 4     0.093651  0.096927  0.090457  0.092533  0.094398  0.093241  0.093714
# ...        ...       ...       ...       ...       ...       ...       ...
# 1229  0.747698  0.136657  0.495951  0.947202  0.102705  0.225916  0.154620
# 1230  0.727684  0.137495  0.520706  0.952286  0.102495  0.226340  0.155597
# 1231  0.704916  0.138933  0.522551  0.947533  0.105925  0.226255  0.154635
# 1232  0.699524  0.139638  0.536577  0.956826  0.106602  0.231322  0.153516
# 1233  0.699486  0.137802  0.512157  0.934598  0.105409  0.223584  0.153138
#
#             7         8         9         10
# 0     0.090909  0.090909  0.090909  0.090909
# 1     0.090808  0.093520  0.092206  0.089922
# 2     0.091263  0.097371  0.092280  0.087618
# 3     0.090101  0.099270  0.095528  0.088408
# 4     0.089091  0.099197  0.095240  0.093608
# ...        ...       ...       ...       ...
# 1229  0.230253  0.467178  0.183087  0.259496
# 1230  0.233737  0.469642  0.180352  0.257718
# 1231  0.236667  0.474717  0.185519  0.257718
# 1232  0.241919  0.466174  0.189794  0.257587
# 1233  0.241263  0.461774  0.181375  0.261339
#
# [1234 rows x 11 columns]

# %%
data = tf.divide(tf_port_data, tf_port_data[0])  
data.shape
# Out:
# TensorShape([1234, 11])

# %% [markdown]
# # Deep learning Model for Portfolio Optimization [Method 2] (Not important)

# %%
def sharpe_loss_2(_, y_pred):

  y_pred = tf.cast(y_pred, dtype = tf.float64)
  cov_tensor = tf.convert_to_tensor(cov, dtype=tf.float64)
  pct_change_tensor = tf.convert_to_tensor(pct_change, dtype=tf.float64)

  # EXPECTED ANNUAL RETURN
  annual_returns = K.mean(pct_change_tensor) * 252
  # find expected portfolio returns
  expected_return = tf.reduce_sum(tf.transpose(y_pred) * annual_returns)

  # ANNUAL VOLATILITY
  # find annual volatility of portfolio
  volatility = tf.sqrt(tf.matmul(y_pred,tf.matmul(cov_tensor*252,tf.transpose(y_pred))))

  # SHARPE RATIO (Assuming 0 risk free return)
  sharpe_ratio = expected_return / volatility

  if sharpe_ratio > 0:
    return -sharpe_ratio
  else:
    return sharpe_ratio

# %%
def gen_model(input_shape, outputs):
  model = Sequential([
              GRU(128, input_shape=input_shape, return_sequences = True),
              GRU(64),
              Flatten(),
              Dense(outputs, activation='softmax')
          ])

  # FOR TESTING:
  # model.compile(loss=sharpe_loss_2, optimizer='adam', run_eagerly=True)
  
  # FOR PRODUCTION:
  model.compile(loss=sharpe_loss_2, optimizer='adam')

  return model

# %%
# Historical data concatenated with returns (for momentum purpose as explained in the paper "Deep
# learning for portfolio optimization")
df_w_ret = np.concatenate([ df.values[1:], df.pct_change().values[1:] ], axis=1)

# %%
df_w_ret[0]
# Out:
# array([ 1.18330002e+02,  6.15900024e+02,  8.13716202e+01,  4.25000000e+02,
#         9.37150024e+02,  2.24050003e+02,  2.82100006e+02,  8.88000031e+01,
#         2.46300003e+02,  2.59989990e+02,  6.65000000e+01,  1.56209738e-02,
#        -7.49329380e-03,  7.31054078e-03, -2.35253122e-04,  1.07312468e-02,
#        -1.27781182e-02,  9.48289061e-03,  1.71821300e-02,  2.51821147e-02,
#        -4.82300389e-03, -5.23557939e-03])

# %%
opt_model_x = df_w_ret[np.newaxis, :]

opt_model_x.shape
# Out:
# (1, 1235, 22)

# %%
opt_model_2 = gen_model(np.array([opt_model_x.shape[1], opt_model_x.shape[2]]), port_len)

# %%
with tf.device('/device:GPU:0'):
  # Here Y [np.zeros((1, port_len))] does not matter because we don't use y_true in 
  # the custom loss function
  opt_model_2.fit(opt_model_x, np.zeros((1, port_len)), epochs=50, shuffle=False)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 17s 17s/step - loss: -1.4235
# Epoch 2/50
# 1/1 [==============================] - 12s 12s/step - loss: -1.5180
# Epoch 3/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.5441
# Epoch 4/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.5496
# Epoch 5/50
# 1/1 [==============================] - 12s 12s/step - loss: -1.5603
# Epoch 6/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.5730
# Epoch 7/50
# 1/1 [==============================] - 12s 12s/step - loss: -1.5835
# Epoch 8/50
# 1/1 [==============================] - 12s 12s/step - loss: -1.5958
# Epoch 9/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6060
# Epoch 10/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6110
# Epoch 11/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6077
# Epoch 12/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6036
# Epoch 13/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6038
# Epoch 14/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6086
# Epoch 15/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6144
# Epoch 16/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6182
# Epoch 17/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6187
# Epoch 18/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6165
# Epoch 19/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6142
# Epoch 20/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6138
# Epoch 21/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6151
# Epoch 22/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6168
# Epoch 23/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6174
# Epoch 24/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6188
# Epoch 25/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6192
# Epoch 26/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6189
# Epoch 27/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6181
# Epoch 28/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6179
# Epoch 29/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6191
# Epoch 30/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6194
# Epoch 31/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6198
# Epoch 32/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6200
# Epoch 33/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6200
# Epoch 34/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6201
# Epoch 35/50
# 1/1 [==============================] - 12s 12s/step - loss: -1.6201
# Epoch 36/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6200
# Epoch 37/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6200
# Epoch 38/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6200
# Epoch 39/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6202
# Epoch 40/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6139
# Epoch 41/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6199
# Epoch 42/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6192
# Epoch 43/50
# 1/1 [==============================] - 12s 12s/step - loss: -1.6192
# Epoch 44/50
# 1/1 [==============================] - 12s 12s/step - loss: -1.6197
# Epoch 45/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6198
# Epoch 46/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6197
# Epoch 47/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6198
# Epoch 48/50
# 1/1 [==============================] - 11s 11s/step - loss: -1.6203
# Epoch 49/50
# 1/1 [==============================] - 12s 12s/step - loss: -1.6203
# Epoch 50/50
# 1/1 [==============================] - 12s 12s/step - loss: -1.6201

# %%
pred_weights_2 = opt_model_2.predict(opt_model_x).T
pred_weights_2 = pd.DataFrame(pred_weights_2)
pred_weights_2
# Out:
#            0
# 0   0.044639
# 1   0.196646
# 2   0.005666
# 3   0.076830
# 4   0.206292
# 5   0.006700
# 6   0.061958
# 7   0.029194
# 8   0.118983
# 9   0.248855
# 10  0.004236

# %%
erDL, cvDL, srDL = get_port_stats(pct_change, pred_weights_2, cov)
# Out:
# Expected Returns: 23.9%
# Annual Volatility: 20.22%
# Sharpe Ratio: 1.18

# %% [markdown]
# # Statistical models (PyPortfolioOpt)

# %%
from pypfopt import HRPOpt
from pypfopt import CLA
from pypfopt import plotting
from pypfopt import risk_models
from pypfopt import expected_returns

# %%
pct_change.plot(label = tickers, figsize = (15,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## HRP (Hierarchical Risk Parity)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here since Minimum variance portfolio is formed, the returns will obviously be low.

# %%
# Using Hierarchical Risk Parity method to compute optimized portfolio weights
hrp = HRPOpt(pct_change)
hrp.optimize()
weights = hrp.clean_weights()
weights
# Out:
# OrderedDict([('APLAPOLLO.NS', 0.07555),
#              ('BLUESTARCO.NS', 0.16058),
#              ('BSOFT.NS', 0.06281),
#              ('COFORGE.NS', 0.0772),
#              ('CUMMINSIND.NS', 0.11475),
#              ('DHAMPURSUG.NS', 0.04249),
#              ('SBIN.NS', 0.06951),
#              ('TATAPOWER.NS', 0.06272),
#              ('TRENT.NS', 0.10267),
#              ('VTL.NS', 0.17944),
#              ('ZENTEC.NS', 0.05229)])

# %%
risk_models.sample_cov(df) # covariance matrix
# Out:
#                APLAPOLLO.NS  BLUESTARCO.NS  BSOFT.NS  COFORGE.NS  \
# APLAPOLLO.NS       0.168916       0.034822  0.049316    0.042962
# BLUESTARCO.NS      0.034822       0.105891  0.034940    0.030138
# BSOFT.NS           0.049316       0.034940  0.224762    0.084754
# COFORGE.NS         0.042962       0.030138  0.084754    0.203918
# CUMMINSIND.NS      0.032724       0.021569  0.041685    0.024653
# DHAMPURSUG.NS      0.046278       0.033196  0.056976    0.042226
# SBIN.NS            0.038809       0.030066  0.052254    0.036698
# TATAPOWER.NS       0.044963       0.033819  0.053737    0.040421
# TRENT.NS           0.044841       0.027830  0.040679    0.041323
# VTL.NS             0.027901       0.018104  0.023194    0.015002
# ZENTEC.NS          0.055513       0.032570  0.067100    0.046052
#
#                CUMMINSIND.NS  DHAMPURSUG.NS   SBIN.NS  TATAPOWER.NS  TRENT.NS  \
# APLAPOLLO.NS        0.032724       0.046278  0.038809      0.044963  0.044841
# BLUESTARCO.NS       0.021569       0.033196  0.030066      0.033819  0.027830
# BSOFT.NS            0.041685       0.056976  0.052254      0.053737  0.040679
# COFORGE.NS          0.024653       0.042226  0.036698      0.040421  0.041323
# CUMMINSIND.NS       0.111212       0.036418  0.037039      0.038856  0.024496
# DHAMPURSUG.NS       0.036418       0.332264  0.060985      0.061811  0.035328
# SBIN.NS             0.037039       0.060985  0.143525      0.063949  0.041613
# TATAPOWER.NS        0.038856       0.061811  0.063949      0.159067  0.041366
# TRENT.NS            0.024496       0.035328  0.041613      0.041366  0.138244
# VTL.NS              0.013455       0.035455  0.025455      0.029384  0.020466
# ZENTEC.NS           0.039587       0.063316  0.048146      0.058985  0.039473
#
#                  VTL.NS  ZENTEC.NS
# APLAPOLLO.NS   0.027901   0.055513
# BLUESTARCO.NS  0.018104   0.032570
# BSOFT.NS       0.023194   0.067100
# COFORGE.NS     0.015002   0.046052
# CUMMINSIND.NS  0.013455   0.039587
# DHAMPURSUG.NS  0.035455   0.063316
# SBIN.NS        0.025455   0.048146
# TATAPOWER.NS   0.029384   0.058985
# TRENT.NS       0.020466   0.039473
# VTL.NS         0.105252   0.033973
# ZENTEC.NS      0.033973   0.361200

# %%
weightsdf1 = pd.DataFrame.from_dict(weights, orient="index")
weightsdf1 = weightsdf1.rename({0: 'weights'}, axis=1)
weightsdf1
# Out:
#                weights
# APLAPOLLO.NS   0.07555
# BLUESTARCO.NS  0.16058
# BSOFT.NS       0.06281
# COFORGE.NS     0.07720
# CUMMINSIND.NS  0.11475
# DHAMPURSUG.NS  0.04249
# SBIN.NS        0.06951
# TATAPOWER.NS   0.06272
# TRENT.NS       0.10267
# VTL.NS         0.17944
# ZENTEC.NS      0.05229

# %%
plotting.plot_weights(weights)
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
weightsdf1.iloc[:, 0].sum()
# Out:
# 1.00001

# %%
hrp.portfolio_performance(risk_free_rate=0, verbose=True)
# Out:
# Expected annual return: 28.7%
# Annual volatility: 21.1%
# Sharpe Ratio: 1.36
# (0.2869746544621335, 0.21089594422446492, 1.360740508867705)

# %%
erW1Plib, cvW1Plib, srW1Plib = get_port_stats(pct_change, weightsdf1, cov)
# Out:
# Expected Returns: 28.7%
# Annual Volatility: 21.09%
# Sharpe Ratio: 1.36

# %%
plotting.plot_dendrogram(hrp)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## CLA (Critical Line Algorithm)

# %%
mu = expected_returns.mean_historical_return(df)
S = risk_models.sample_cov(df) # covariance matrix

# %%
mu
# Out:
# APLAPOLLO.NS     0.551159
# BLUESTARCO.NS    0.111137
# BSOFT.NS         0.439039
# COFORGE.NS       0.616060
# CUMMINSIND.NS    0.031962
# DHAMPURSUG.NS    0.214024
# SBIN.NS          0.121512
# TATAPOWER.NS     0.277146
# TRENT.NS         0.384953
# VTL.NS           0.107057
# ZENTEC.NS        0.247710
# dtype: float64

# %%
S
# Out:
#                APLAPOLLO.NS  BLUESTARCO.NS  BSOFT.NS  COFORGE.NS  \
# APLAPOLLO.NS       0.168916       0.034822  0.049316    0.042962
# BLUESTARCO.NS      0.034822       0.105891  0.034940    0.030138
# BSOFT.NS           0.049316       0.034940  0.224762    0.084754
# COFORGE.NS         0.042962       0.030138  0.084754    0.203918
# CUMMINSIND.NS      0.032724       0.021569  0.041685    0.024653
# DHAMPURSUG.NS      0.046278       0.033196  0.056976    0.042226
# SBIN.NS            0.038809       0.030066  0.052254    0.036698
# TATAPOWER.NS       0.044963       0.033819  0.053737    0.040421
# TRENT.NS           0.044841       0.027830  0.040679    0.041323
# VTL.NS             0.027901       0.018104  0.023194    0.015002
# ZENTEC.NS          0.055513       0.032570  0.067100    0.046052
#
#                CUMMINSIND.NS  DHAMPURSUG.NS   SBIN.NS  TATAPOWER.NS  TRENT.NS  \
# APLAPOLLO.NS        0.032724       0.046278  0.038809      0.044963  0.044841
# BLUESTARCO.NS       0.021569       0.033196  0.030066      0.033819  0.027830
# BSOFT.NS            0.041685       0.056976  0.052254      0.053737  0.040679
# COFORGE.NS          0.024653       0.042226  0.036698      0.040421  0.041323
# CUMMINSIND.NS       0.111212       0.036418  0.037039      0.038856  0.024496
# DHAMPURSUG.NS       0.036418       0.332264  0.060985      0.061811  0.035328
# SBIN.NS             0.037039       0.060985  0.143525      0.063949  0.041613
# TATAPOWER.NS        0.038856       0.061811  0.063949      0.159067  0.041366
# TRENT.NS            0.024496       0.035328  0.041613      0.041366  0.138244
# VTL.NS              0.013455       0.035455  0.025455      0.029384  0.020466
# ZENTEC.NS           0.039587       0.063316  0.048146      0.058985  0.039473
#
#                  VTL.NS  ZENTEC.NS
# APLAPOLLO.NS   0.027901   0.055513
# BLUESTARCO.NS  0.018104   0.032570
# BSOFT.NS       0.023194   0.067100
# COFORGE.NS     0.015002   0.046052
# CUMMINSIND.NS  0.013455   0.039587
# DHAMPURSUG.NS  0.035455   0.063316
# SBIN.NS        0.025455   0.048146
# TATAPOWER.NS   0.029384   0.058985
# TRENT.NS       0.020466   0.039473
# VTL.NS         0.105252   0.033973
# ZENTEC.NS      0.033973   0.361200

# %%
cla = CLA(mu, S)
cla.max_sharpe()
weights2 = cla.clean_weights()
weightsdf2 = pd.DataFrame.from_dict(weights2, orient="index")
weightsdf2 = weightsdf2.rename({0: 'weights'}, axis=1)
weightsdf2
# Out:
#                weights
# APLAPOLLO.NS   0.36543
# BLUESTARCO.NS  0.00000
# BSOFT.NS       0.06761
# COFORGE.NS     0.34184
# CUMMINSIND.NS  0.00000
# DHAMPURSUG.NS  0.00000
# SBIN.NS        0.00000
# TATAPOWER.NS   0.01686
# TRENT.NS       0.20827
# VTL.NS         0.00000
# ZENTEC.NS      0.00000

# %%
plotting.plot_weights(weights2)
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
erW2Plib, cvW2Plib, srW2Plib = cla.portfolio_performance(risk_free_rate=0, verbose=True)
erW2Plib, cvW2Plib, srW2Plib = (erW2Plib * 100).round(decimals = 2), (cvW2Plib * 100).round(decimals = 2), (srW2Plib).round(decimals = 2)
# Out:
# Expected annual return: 52.7%
# Annual volatility: 29.3%
# Sharpe Ratio: 1.80

# %%
plotting.plot_efficient_frontier(cla)
# Out:
# <AxesSubplot:xlabel='Volatility', ylabel='Return'>

# %% [markdown]
# # Statistical Models (RiskFolio-Lib) [Best Library]

# %%
# Calculating returns
Y = pct_change
Y
# Out:
#             ADANIPORTS.NS  ASIANPAINT.NS  BHARTIARTL.NS  CIPLA.NS  \
# Date
# 2017-05-09       0.020558      -0.001756      -0.017222  0.002538
# 2017-05-10       0.012662      -0.006007       0.079652  0.014649
# 2017-05-11       0.023160       0.007036      -0.018109  0.001604
# 2017-05-12      -0.005832      -0.028720      -0.002459  0.010677
# 2017-05-15      -0.004889       0.013328      -0.002602  0.001849
# ...                   ...            ...            ...       ...
# 2022-04-29      -0.034607      -0.003233      -0.011173  0.000000
# 2022-05-02       0.000175      -0.011491       0.003180 -0.004688
# 2022-05-04      -0.051077      -0.030984      -0.025561 -0.019506
# 2022-05-05      -0.001784      -0.007837      -0.004776 -0.009556
# 2022-05-06       0.000062      -0.019600      -0.012101 -0.014393
#
#             HDFCBANK.NS  ICICIBANK.NS   INFY.NS  LUPIN.NS  RELIANCE.NS  \
# Date
# 2017-05-09     0.000619     -0.007757  0.001216 -0.023168     0.006773
# 2017-05-10     0.010451     -0.006487 -0.003169  0.006999     0.021611
# 2017-05-11    -0.003480      0.005190  0.000477  0.000635     0.000331
# 2017-05-12     0.003395     -0.012159  0.021343 -0.004565    -0.006693
# 2017-05-15     0.001128      0.017704 -0.013171  0.024363    -0.004702
# ...                 ...           ...       ...       ...          ...
# 2022-04-29     0.009662     -0.005153 -0.009510 -0.005343    -0.010497
# 2022-05-02     0.013795     -0.003094 -0.016937 -0.003760    -0.003512
# 2022-05-04    -0.033982     -0.022605 -0.003537 -0.020354    -0.031218
# 2022-05-05    -0.002249      0.006282  0.032301 -0.000550    -0.019583
# 2022-05-06    -0.026128     -0.013104 -0.026685 -0.003442    -0.007668
#
#               TCS.NS
# Date
# 2017-05-09  0.004312
# 2017-05-10 -0.008544
# 2017-05-11  0.007288
# 2017-05-12  0.004767
# 2017-05-15  0.001885
# ...              ...
# 2022-04-29 -0.010490
# 2022-05-02 -0.001212
# 2022-05-04 -0.017686
# 2022-05-05  0.009670
# 2022-05-06 -0.022998
#
# [1235 rows x 10 columns]

# %% [markdown]
# ## Calculating CVaR for each asset of portfolio and reduction factor [Not important]

# %%
# Calculating CVaR for first asset - Using original formula
Y.iloc[:, 0].sort_values(ascending=False).tail(int(.05 * len(Y))).mean()
# Out:
# -0.05348735228129678

# %%
cvar_df = get_CVaR(Y)
cvar_df
# Out:
# The worst case loss for AARTIDRUGS.NS is 5.5% and we can conclude this with a confidence of 95%.
# The worst case loss for BSOFT.NS is 6.93% and we can conclude this with a confidence of 95%.
# The worst case loss for GTPL.NS is 7.25% and we can conclude this with a confidence of 95%.
# The worst case loss for ISEC.NS is 6.0% and we can conclude this with a confidence of 95%.
# The worst case loss for LINCOLN.NS is 5.96% and we can conclude this with a confidence of 95%.
# The worst case loss for SPAL.NS is 6.59% and we can conclude this with a confidence of 95%.
# The worst case loss for TIRUMALCHM.NS is 7.59% and we can conclude this with a confidence of 95%.
#                       0
# AARTIDRUGS.NS  0.054997
# BSOFT.NS       0.069273
# GTPL.NS        0.072450
# ISEC.NS        0.059969
# LINCOLN.NS     0.059590
# SPAL.NS        0.065933
# TIRUMALCHM.NS  0.075880

# %%
rf = get_reduction_factor(cvar_df[0])
rf
# Out:
# array([[1.        ],
#        [0.82910578],
#        [0.79106654],
#        [0.94048687],
#        [0.94501827],
#        [0.8690817 ],
#        [0.75      ]])

# %%
rf_mul_weights = np.multiply(rf, np.array([1 / port_len for x in range(port_len)]).T.reshape(-1,1))
rf_mul_weights
# Out:
# array([[0.14285714],
#        [0.11844368],
#        [0.11300951],
#        [0.13435527],
#        [0.13500261],
#        [0.12415453],
#        [0.10714286]])

# %%
new_weights = softmax(rf_mul_weights)
new_weights
# Out:
# array([[0.14542127],
#        [0.14191402],
#        [0.14114493],
#        [0.14419016],
#        [0.14428353],
#        [0.14272679],
#        [0.1403193 ]])

# %% [markdown]
# ## HRP (Hierarchical Risk Parity)
#
# Reference - https://hudsonthames.org/an-introduction-to-the-hierarchical-risk-parity-algorithm/
#
# ### Risk measures - CVaR, CDaR, Ulcer Index
#
# Different risk measures interpret risk in different ways.

# %%
model='HRP' # Could be HRP or HERC
codependence = 'pearson' # Correlation matrix used to group assets in clusters
# Risk Measure - Conditional Value at Risk
# rm = 'CVaR'
# Risk Measure - Conditional Drawdown at Risk of uncompounded cumulative returns
# rm = 'CDaR'
# Risk Measure - Ulcer Index of uncompounded cumulative returns.
rm = 'UCI'
rf = 0 # Risk free rate
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
linkage = 'single' # Linkage method used to build clusters
leaf_order = True # Consider optimal order of leafs in dendrogram
hist = True # Use historical scenarios for risk measures that depend on scenarios
max_k = port_len

# %%
# Plotting Assets Clusters

ax = rp.plot_clusters(returns=Y,
                      codependence=codependence,
                      linkage=linkage,
                      k=None,
                      max_k=max_k,
                      leaf_order=leaf_order,
                      ax=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/riskfolio/PlotFunctions.py:2237: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
# Building the portfolio object
port1 = rp.HCPortfolio(returns=Y)

# %%
# Estimate optimal portfolio:

w1 = port1.optimization(model=model,
                      codependence=codependence,
                      rm=rm,
                      rf=rf,
                      obj=obj,
                      linkage=linkage,
                      leaf_order=leaf_order,
                      hist=hist)

display(w1.T)
# Out:
#          ADANIPORTS.NS  ASIANPAINT.NS  BHARTIARTL.NS  CIPLA.NS  HDFCBANK.NS  \
# weights       0.075114       0.172175       0.075628  0.105423     0.124425
#
#          ICICIBANK.NS   INFY.NS  LUPIN.NS  RELIANCE.NS    TCS.NS
# weights       0.07351  0.101094  0.049928     0.123748  0.098954

# %%
# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w1,
                 title='HRP Naive Risk Parity',
                 others=0,
                 nrow=25,
                 cmap="tab20",
                 height=8,
                 width=15,
                 ax=None)

# %%
# Plotting the risk contribution graph of each asset

ax = rp.plot_risk_con(w=w1,
                 cov=port1.cov, 
                 returns=port1.returns, 
                 ax=None)

# %%
erW1, cvW1, srW1 = get_port_stats(port1.returns, w1, port1.cov)
# Out:
# Expected Returns: 21.86%
# Annual Volatility: 17.59%
# Sharpe Ratio: 1.24

# %% [markdown]
# ## HERC (Hierarchical Equal Risk Contribution)
#
# Reference - https://hudsonthames.org/beyond-risk-parity-the-hierarchical-equal-risk-contribution-algorithm/
#
# ### Risk measures - CVaR, CDaR, Ulcer Index
#
# Different risk measures interpret risk in different ways.

# %%
model='HERC' # Could be HRP or HERC
codependence = 'pearson' # Correlation matrix used to group assets in clusters
# Risk Measure - Conditional Value at Risk
# rm = 'CVaR'
# Risk Measure - Conditional Drawdown at Risk of uncompounded cumulative returns
# rm = 'CDaR'
# Risk Measure - Ulcer Index of uncompounded cumulative returns.
rm = 'UCI'
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
rf = 0 # Risk free rate
linkage = 'complete' # Linkage method used to build clusters
max_k = port_len # Max number of clusters used in two difference gap statistic, only for HERC model
leaf_order = True # Consider optimal order of leafs in dendrogram
hist = True # Use historical scenarios for risk measures that depend on scenarios

# %%
ax = rp.plot_clusters(returns=Y,
                      codependence=codependence,
                      linkage=linkage,
                      k=None,
                      max_k=max_k,
                      leaf_order=leaf_order,
                      ax=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/riskfolio/PlotFunctions.py:2237: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
# Building the portfolio object
port2 = rp.HCPortfolio(returns=Y)

# %%
# Estimate optimal portfolio:

w2 = port2.optimization(model=model,
                      codependence=codependence,
                      rm=rm,
                      rf=rf,
                      obj=obj,
                      linkage=linkage,
                      max_k=max_k,
                      leaf_order=leaf_order,
                      hist=hist)

display(w2.T)
# Out:
#          ADANIPORTS.NS  ASIANPAINT.NS  BHARTIARTL.NS  CIPLA.NS  HDFCBANK.NS  \
# weights       0.006483       0.012271       0.011997  0.472828     0.009711
#
#          ICICIBANK.NS  INFY.NS  LUPIN.NS  RELIANCE.NS   TCS.NS
# weights      0.006344  0.12471  0.223929     0.009658  0.12207

# %%
# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w2,
                 title='HERC Naive Risk Parity',
                 others=0,
                 nrow=25,
                 cmap="tab20",
                 height=8,
                 width=15,
                 ax=None)

# %%
# Plotting the risk contribution graph of each asset

ax = rp.plot_risk_con(w=w2,
                 cov=port2.cov, 
                 returns=port2.returns, 
                 ax=None)

# %%
erW2, cvW2, srW2 = get_port_stats(port2.returns, w2, port2.cov)
# Out:
# Expected Returns: 13.5%
# Annual Volatility: 20.97%
# Sharpe Ratio: 0.64

# %% [markdown]
# # Comparsion of HRP, HERC and DL models

# %%
comparison_models_len = 3

# %%
# pred_weights_1_index_changed = pred_weights_1.reset_index(drop = True)
# pred_weights_1_index_changed = pred_weights_1_index_changed.set_index(w1.index)

# USING LIMITED WEIGHTS
pred_weights_1_index_changed = pred_weights_limited.reset_index(drop = True)
pred_weights_1_index_changed = pred_weights_1_index_changed.set_index(w1.index)
pred_weights_1_index_changed = pred_weights_1_index_changed.rename({0: 'weights'}, axis=1)

# pred_weights_2_index_changed = pred_weights_2.reset_index(drop = True)
# pred_weights_2_index_changed = pred_weights_2_index_changed.set_index(w1.index)
# pred_weights_2_index_changed = pred_weights_2_index_changed.rename({0: 'weights'}, axis=1)

# %%
compare_dl_w1_w2 = pd.concat([pred_weights_1_index_changed,
                              # pred_weights_2_index_changed, 
                              #weightsdf1,
                              w1,
                              #weightsdf2,
                              w2], 
                             keys=["DL Model Weights",
                                   # "DL Model Weights (Method 2)", 
                                   #"HRP Weights (PyPortfolioOpt)",
                                   "HRP Weights (Riskfolio lib)",
                                   #"CLA (PyPortfolioOpt)", 
                                   "HERC Weights (Riskfolio lib)"], 
                             axis= 1)

compare_dl_w1_w2
# Out:
#               DL Model Weights HRP Weights (Riskfolio lib)  \
#                        weights                     weights
# ADANIPORTS.NS           0.0491                    0.075114
# ASIANPAINT.NS           0.2150                    0.172175
# BHARTIARTL.NS           0.1010                    0.075628
# CIPLA.NS                0.0274                    0.105423
# HDFCBANK.NS             0.0150                    0.124425
# ICICIBANK.NS            0.0229                    0.073510
# INFY.NS                 0.1708                    0.101094
# LUPIN.NS                0.0172                    0.049928
# RELIANCE.NS             0.1348                    0.123748
# TCS.NS                  0.2469                    0.098954
#
#               HERC Weights (Riskfolio lib)
#                                    weights
# ADANIPORTS.NS                     0.006483
# ASIANPAINT.NS                     0.012271
# BHARTIARTL.NS                     0.011997
# CIPLA.NS                          0.472828
# HDFCBANK.NS                       0.009711
# ICICIBANK.NS                      0.006344
# INFY.NS                           0.124710
# LUPIN.NS                          0.223929
# RELIANCE.NS                       0.009658
# TCS.NS                            0.122070

# %%
def get_stats_df(er, cv, sr, col_name):
  stats_df = pd.DataFrame(np.array([er, cv, sr]).T, index=["Expected Returns", "Annual Volatility", "Sharpe Ratio"])
  stats_df = stats_df.rename({ 0: col_name }, axis = 1)
  
  return stats_df

# %%
port_stats_dl1_dl2_w1_w2 = pd.concat([get_stats_df(erDLm1, cvDLm1, srDLm1, "DL Model"),
                                 # get_stats_df(erDL, cvDL, srDL, "DL Model (Method 2)"),
                                 #get_stats_df(erW1Plib, cvW1Plib, srW1Plib, 
                                 #             "HRP (PyPortfolioOpt)"),
                                 get_stats_df(erW1, cvW1, srW1, "HRP (Riskfolio lib)"),
                                 #get_stats_df(erW2Plib, cvW2Plib, srW2Plib, "CLA (PyPortfolioOpt)"),
                                 get_stats_df(erW2, cvW2, srW2, "HERC (Riskfolio lib)")], 
                                axis = 1)

port_stats_dl1_dl2_w1_w2
# Out:
#                    DL Model  HRP (Riskfolio lib)  HERC (Riskfolio lib)
# Expected Returns      24.99                21.86                 13.50
# Annual Volatility     18.18                17.59                 20.97
# Sharpe Ratio           1.37                 1.24                  0.64

# %% [markdown]
# ## Plotting Risk contribution of each asset for each method

# %%
colors = ["blue", "red", "green", "yellow", "pink"]
# weights_list = [pred_weights_1_index_changed, weightsdf1, w1, weightsdf2, w2] 
weights_list = [pred_weights_1_index_changed, w1, w2] 
title_list = ["DL Model Weights",
            #"HRP Weights (PyPortfolioOpt)",
            "HRP Weights (Riskfolio lib)",
            #"CLA (PyPortfolioOpt)", 
            "HERC Weights (Riskfolio lib)"]

# %%
# Plotting the risk contribution graph of each asset for each comparison method

figure, axis = plt.subplots(comparison_models_len, 1, figsize=(24,48), facecolor=(1, 1, 1)) # (rows, cols, figsize, facecolor)

for i in range(comparison_models_len):
  rp.plot_risk_con(w=weights_list[i],
                  cov=cov, 
                  color=colors[i],
                  returns=pct_change,
                  ax = axis[i])
  
  axis[i].set_title(title_list[i] + " - Risk contribution per asset")

# %% [markdown]
# # Final output generator

# %%
def get_final_score(dl_weights, stat_weight_1, stat_weight_2, fundamentals_analyser_score):
  max_w_alloc_count = math.ceil(port_len / 3)
  avg_w_alloc_count = math.ceil(port_len / 3)
  min_w_alloc_count = port_len - (max_w_alloc_count + avg_w_alloc_count)

  final_score_without_softmax_dict = {}

  # Allocating maximum weight from the three models to the most fundamentally strong assets
  for i in range(max_w_alloc_count):

    cur_asset = fundamentals_analyser_score[i][0]
    alloc_weight = max(dl_weights[cur_asset], 
                                           stat_weight_1[cur_asset], 
                                           stat_weight_2[cur_asset])
    final_score_without_softmax_dict[cur_asset] = alloc_weight
    
  # Allocating average weight from the three models to assets with average fundamentals
  for i in range(max_w_alloc_count, max_w_alloc_count + avg_w_alloc_count):

    cur_asset = fundamentals_analyser_score[i][0]
    alloc_weight = (dl_weights[cur_asset] +
                                  stat_weight_1[cur_asset] + 
                                  stat_weight_2[cur_asset]) / 3
    final_score_without_softmax_dict[cur_asset] = alloc_weight
    
  # Allocating minimum weight from the three models to least fundamentally strong assets
  for i in range(max_w_alloc_count + avg_w_alloc_count, port_len):

    cur_asset = fundamentals_analyser_score[i][0]
    alloc_weight = min(dl_weights[cur_asset], 
                      stat_weight_1[cur_asset], 
                      stat_weight_2[cur_asset])
    final_score_without_softmax_dict[cur_asset] = alloc_weight 

  sorted_dict = dict(sorted(final_score_without_softmax_dict.items()))
  weights_only = np.array([sorted_dict[i] for i in sorted_dict])
  final_weights = softmax(weights_only)
  dict_keys = list(sorted_dict.keys())
  
  final_weights_dict = {}

  for i in range(port_len):
    final_weights_dict[dict_keys[i]] = final_weights[i]

  return final_weights_dict, final_weights

# %%
final_weights_dict, final_weights = get_final_score(pred_weights_1_index_changed.to_dict()['weights'],
                w1.to_dict()['weights'],
                w2.to_dict()['weights'], 
                sorted_score_dict)

final_weights_dict
# Out:
# {'ADANIPORTS.NS': 0.08845461232499091,
#  'ASIANPAINT.NS': 0.1089628251434624,
#  'BHARTIARTL.NS': 0.08894367843678913,
#  'CIPLA.NS': 0.10754296844192959,
#  'HDFCBANK.NS': 0.09236227739504384,
#  'ICICIBANK.NS': 0.09094529735281028,
#  'INFY.NS': 0.10425155434244136,
#  'LUPIN.NS': 0.1099401177914142,
#  'RELIANCE.NS': 0.09610189442292025,
#  'TCS.NS': 0.11249477434819818}

# %%
final_weights_df = pd.DataFrame(final_weights)
final_weights_df = final_weights_df.reset_index(drop = True)
final_weights_df = final_weights_df.set_index(w1.index)
final_weights_df = final_weights_df.rename({0: 'weights'}, axis=1)

final_weights_df
# Out:
#                 weights
# ADANIPORTS.NS  0.088455
# ASIANPAINT.NS  0.108963
# BHARTIARTL.NS  0.088944
# CIPLA.NS       0.107543
# HDFCBANK.NS    0.092362
# ICICIBANK.NS   0.090945
# INFY.NS        0.104252
# LUPIN.NS       0.109940
# RELIANCE.NS    0.096102
# TCS.NS         0.112495

# %%
er, cv, sr = get_port_stats(pct_change, final_weights_df, cov)
# Out:
# Expected Returns: 20.17%
# Annual Volatility: 17.6%
# Sharpe Ratio: 1.15

# %%
figure, axis = plt.subplots(1, 1, figsize=(24,48), facecolor=(1, 1, 1))

rp.plot_risk_con(w=final_weights_df,
                  cov=cov, 
                  color="red",
                  returns=pct_change,
                  ax = None)
# Out:
# <AxesSubplot:title={'center':'Risk (Standard Deviation) Contribution per Asset'}>

# %% [markdown]
# # Finding amount and shares to be allocated to each asset in portfolio based on user budget

# %%
def get_allocations(weights, budget, tickers):

  alloc_amt = dict()
  alloc_shares = dict()

  for t in tickers:
    amt_allocated_for_ticker = round(weights.loc[t, "weights"] * budget, 2)
    alloc_amt[t] = amt_allocated_for_ticker
    alloc_shares[t] = int(amt_allocated_for_ticker // extra_info_tickers.tickers[t].info["regularMarketPrice"])

  return alloc_amt, alloc_shares

# %%
# getting amount and share allocations of each stock for a budget of 10 lakhs 
amt_allocated, shares_allocated = get_allocations(final_weights_df, 1000000, tickers)

# %%
print('Amount allocated for each stock in portfolio')
amt_allocated
# Out:
# Amount allocated for each stock in portfolio
# {'ADANIPORTS.NS': 88454.61,
#  'ASIANPAINT.NS': 108962.83,
#  'BHARTIARTL.NS': 88943.68,
#  'CIPLA.NS': 107542.97,
#  'HDFCBANK.NS': 92362.28,
#  'ICICIBANK.NS': 90945.3,
#  'INFY.NS': 104251.55,
#  'LUPIN.NS': 109940.12,
#  'RELIANCE.NS': 96101.89,
#  'TCS.NS': 112494.77}

# %%
print('Shares allocated for each stock in portfolio')
shares_allocated
# Out:
# Shares allocated for each stock in portfolio
# {'ADANIPORTS.NS': 109,
#  'ASIANPAINT.NS': 36,
#  'BHARTIARTL.NS': 125,
#  'CIPLA.NS': 115,
#  'HDFCBANK.NS': 70,
#  'ICICIBANK.NS': 126,
#  'INFY.NS': 67,
#  'LUPIN.NS': 151,
#  'RELIANCE.NS': 36,
#  'TCS.NS': 32}
